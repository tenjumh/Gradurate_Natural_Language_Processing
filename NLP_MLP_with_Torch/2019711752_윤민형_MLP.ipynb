# %%
# !pip install PyKomoran

# %%
import json
from PyKomoran import *
from sklearn.feature_extraction.text import TfidfVectorizer
import torch
import numpy as np
import random

# %%
def set_seed():
  random.seed(777)
  np.random.seed(777)
  torch.manual_seed(777)
  if torch.cuda.is_available():
    torch.cuda.manual_seed_all(777)

set_seed()

# %%
label_list = ['opening', 'request', 'wh-question', 'yn-question', 'inform', 'affirm', 'ack', 'expressive']
label_map = {label: i for i, label in enumerate(label_list)}

# %%
komoran = Komoran("EXP")

with open('./SpeechAct_tr.json', 'r', encoding='utf-8') as read_file:
    data = json.load(read_file)

tfidf_word = []
tfidf_label = []
for key in data:
  if data[key] == 0:
    continue
  for message in range(len(data[key])):
    komoran_text = ' '.join(komoran.get_morphes_by_tags(data[key][message][1],
                                                        tag_list=['NNP', 'NNG', 'VV']))
    tfidf_word.append(komoran_text)
    komoran_label = data[key][message][2]
    tfidf_label.append(komoran_label)

tfidfvect = TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b', stop_words=None)
tfidfvect.fit_transform(tfidf_word)
# Out:
# <5825x743 sparse matrix of type '<class 'numpy.float64'>'
# 	with 13869 stored elements in Compressed Sparse Row format>

# %%
train_label_list = []
for i in tfidf_label:
  if i in label_map.keys():
    train_label_list.append(label_map[i])
train_tfidf_list = tfidfvect.transform(tfidf_word).toarray().tolist()

# %%
print(len(train_tfidf_list), len(train_label_list))
# Out:
# 5825 5825

# %%
train_label_list
# Out:
# [0,
#  0,
#  1,
#  2,
#  4,
#  4,
#  2,
#  4,
#  2,
#  4,
#  4,
#  2,
#  4,
#  2,
#  4,
#  1,
#  4,
#  3,
#  4,
#  2,
#  4,
#  5,
#  7,
#  7,
#  0,
#  0,
#  1,
#  2,
#  4,
#  4,
#  2,
#  4,
#  2,
#  4,
#  4,
#  2,
#  4,
#  2,
#  4,
#  3,
#  4,
#  2,
#  4,
#  5,
#  7,
#  7,
#  0,
#  0,
#  1,
#  2,
#  4,
#  2,
#  4,
#  1,
#  4,
#  2,
#  4,
#  2,
#  4,
#  1,
#  4,
#  2,
#  4,
#  2,
#  4,
#  4,
#  1,
#  4,
#  7,
#  7,
#  0,
#  0,
#  1,
#  2,
#  4,
#  2,
#  4,
#  2,
#  4,
#  2,
#  4,
#  2,
#  4,
#  2,
#  4,
#  4,
#  1,
#  4,
#  7,
#  7,
#  0,
#  0,
#  1,
#  2,
#  4,
#  4,
#  2,
#  4,
#  2,
#  1,
#  4,
#  4,
#  4,
#  2,
#  4,
#  2,
#  4,
#  3,
#  4,
#  2,
#  4,
#  4,
#  7,
#  7,
#  0,
#  0,
#  1,
#  2,
#  4,
#  2,
#  4,
#  2,
#  4,
#  2,
#  4,
#  2,
#  4,
#  2,
#  4,
#  4,
#  1,
#  4,
#  7,
#  7,
#  0,
#  0,
#  1,
#  2,
#  4,
#  2,
#  4,
#  2,
#  4,
#  2,
#  4,
#  2,
#  4,
#  2,
#  4,
#  4,
#  1,
#  4,
#  7,
#  7,
#  0,
#  0,
#  1,
#  2,
#  4,
#  4,
#  2,
#  4,
#  2,
#  4,
#  4,
#  2,
# ...
