# %%
import json
from PyKomoran import *
import csv
import pandas as pd # 데이터프레임 사용을 위해
from math import log # IDF 계산을 위해

komoran = Komoran("EXP")

with open('C:/Users/fxk/PycharmProjects/tenjumh/Natural_Language_Processing/NLP_Gradurate/SpeechAct.json', 'r', encoding='utf-8') as read_file:
    data = json.load(read_file)

# %%
docs = []
for key in data.keys():
    text = []
    for message in data[key]:
        komoran_text = komoran.get_plain_text(message[1])
        # print(komoran_text)
        komoran_text = komoran_text.split(' ')
        text.append(komoran_text)
    docs.append(text)
# Out:
# [[['아름/NNP', '아/JKV', '잘/MAG', '자/VV', '았/EP', '니/EF', '?/SF'],
#   ['네/IC', ',/SP', '잘/MAG', '자/VV', '았/EP', '습니다/EF', './SF'],
#   ['아름/NNP',
#    '아/JKV',
#    '일정/NNG',
#    '확인/NNG',
#    '좀/MAG',
#    '하/VV',
#    '아/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['언제/MAG', '일정/NNG', '을/JKO', '확인/NNG', '하/XSV', 'ㄹ까요/EF', '?/SF'],
#   ['다음/NNG',
#    '달/NNG',
#    '일정/NNG',
#    '좀/MAG',
#    '알리/VV',
#    '어/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['네/IC',
#    ',/SP',
#    '오전/NNG',
#    '과/JC',
#    '오후/NNG',
#    '약속/NNG',
#    '이/JKS',
#    '있/VX',
#    '어요/EF',
#    './SF'],
#   ['오전/NNP', '약속/NNG', '장소/NNG', '가/JKS', '어디/NP', '야/JKV', '?/SF'],
#   ['약속/NNG', '장소/NNG', '는/JX', '교보문고/NNP', '이/VCP', 'ㅂ니다/EF', './SF'],
#   ['누구/NP', '랑/JKB', '약속/NNG', '이/VCP', 'ㄴ데/EF', '?/SF'],
#   ['네/IC',
#    ',/SP',
#    '초등학교/NNP',
#    '동창/NNP',
#    '분과/NNG',
#    '의/JKG',
#    '약속/NNG',
#    '이/VCP',
#    '에요/EF',
#    './SF'],
#   ['그/MM', '약속/NNG', '바/NNB', '끼/VV', '었/EP', '어/EF', './SF'],
#   ['어떤/MM', '내용/NNG', '이/JKS', '변경/NNG', '되/XSV', '었/EP', '나요/EF', '?/SF'],
#   ['약속/NNG', '날짜/NNP', '가/JKS', '바뀌/VV', '었/EP', '어/EF', './SF'],
#   ['바뀌/VV',
#    'ㄴ/ETM',
#    '날짜/NNG',
#    '를/JKO',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['4월/NNP',
#    '18/SN',
#    '날/NNG',
#    '로/JKB',
#    '바/NNB',
#    '끼/VV',
#    '었/EP',
#    '어/EF',
#    './SF'],
#   ['다시/MAG',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF',
#    '며칠/NNG',
#    '이/VCP',
#    '라고요/EF',
#    '?/SF'],
#   ['9월', '11일/NNP', '로/JKB', '변경/NNG', '되/XSV', '었/EP', '어/EF', './SF'],
#   ['네/IC',
#    ',/SP',
#    '시간/NNG',
#    '도/JX',
#    '변경/NNG',
#    '되/XSV',
#    '었/EP',
#    '나요/EF',
#    '?/SF'],
#   ['아니/IC',
#    ',/SP',
#    '시간/NNG',
#    '은/JX',
#    '같/VA',
#    '은/ETM',
#    '시간/NNP',
#    '이/VCP',
#    '야/EF',
#    './SF'],
#   ['약속/NNG', '장소/NNG', '는/JX', '어디/NP', '세/VA', '요/EF', '?/SF'],
#   ['씨티/NNG', '문고/NNP', '야/JKV', './SF'],
#   ['네/IC', ',/SP', '일정/NNG', '을/JKO', '변경/NNG', '하/XSV', 'ㅂ니다/EF', './SF'],
#   ['아름/NNP', '아/JKV', '고맙/VA', '어/EF', './SF'],
#   ['또/MAJ', '부르/VV', '어/EC', '주/VX', '시/EP', '어요/EF', './SF']],
#  [['아름/NNP', '아/JKV', '안녕/IC', '?/SF'],
#   ['안녕하세요/NNP', './SF'],
#   ['아름/NNP',
#    '아/JKV',
#    '일정/NNG',
#    '확인/NNG',
#    '좀/MAG',
#    '하/VV',
#    '아/EC',
#    '주/VX',
#    'ㄹ래/EF',
#    '?/SF'],
#   ['네/IC',
#    ',/SP',
#    '언제/MAG',
#    '일정/NNG',
#    '을/JKO',
#    '확인/NNG',
#    '하/XSV',
#    'ㄹ까요/EF',
#    '?/SF'],
#   ['다음/NNG',
#    '달/NNG',
#    '일정/NNG',
#    '좀/MAG',
#    '알리/VV',
#    '어/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['확인/NNG',
#    '하/XSV',
#    'ㅂ니다/EF',
#    './SF',
#    '오전/NNG',
#    '과/JC',
#    '오후/NNG',
#    '약속/NNG',
#    '이/JKS',
#    '있/VX',
#    '습니다/EF',
#    './SF'],
#   ['오전/NNP',
#    '약속/NNG',
#    '장소/NNG',
#    '좀/MAG',
#    '알리/VV',
#    '어/EC',
#    '주/VX',
#    'ㄹ래/EF',
#    '?/SF'],
#   ['네/IC',
#    ',/SP',
#    '약속/NNG',
#    '장소/NNG',
#    '는/JX',
#    '롯데백화점/NNP',
#    '이/VCP',
#    '에요/EF',
#    './SF'],
#   ['아름/NNP', '아/JKV', '누구/NP', '와/JKB', '약속/NNG', '이/VCP', '니/EF', '?/SF'],
#   ['회사/NNG', '동료/NNG', '분과/NNG', '의/JKG', '약속/NNG', '이/VCP', 'ㅂ니다/EF', './SF'],
#   ['약속/NNG', '일정/NNG', '이/JKS', '변경/NNG', '되/XSV', '었/EP', '거든/EF', './SF'],
#   ['어떤/MM', '내용/NNG', '이/JKS', '변경/NNG', '되/XSV', '었/EP', '나요/EF', '?/SF'],
#   ['약속/NNG', '날짜/NNP', '가/JKS', '바/NNB', '끼/VV', '었/EP', '어/EF', './SF'],
#   ['네/IC', ',/SP', '언제/NP', '로/JKB', '바뀌/VV', '었/EP', '나요/EF', '?/SF'],
#   ['12월', '5일/NNP', '로/JKB', '변경/NNG', '되/XSV', '었/EP', '거든/EF', './SF'],
#   ['알/VV',
#    '겠/EP',
#    '습니다/EF',
#    './SF',
#    '시간/NNG',
#    '도/JX',
#    '변경/NNG',
#    '되/XSV',
#    '었/EP',
#    '나요/EF',
#    '?/SF'],
#   ['그래/IC',
#    ',/SP',
#    '시간/NNG',
#    '이/JKS',
#    '30/SN',
#    '분/NNB',
#    '으로/JKB',
#    '변경/NNG',
#    '되/XSV',
#    '었/EP',
#    '어/EF',
#    './SF'],
#   ['약속/NNG',
#    '장소/NNG',
#    '를/JKO',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['장소/NNG',
#    '는/JX',
#    '친구/NNG',
#    '소연/NNP',
#    '이/VCP',
#    '네/EC',
#    '집/NNG',
#    '이/VCP',
#    '야/EF',
#    './SF'],
#   ['네/IC',
#    ',/SP',
#    '일정/NNG',
#    '을/JKO',
#    '변경/NNG',
#    '하/XSV',
#    '았/EP',
#    '습니다/EF',
#    './SF'],
#   ['아름/NNP', '아/JKV', '고맙/VA', '다/EF', './SF'],
#   ['아니/VCN', '에요/EF', './SF']],
#  [['아름/NNP', '아/JKV', './SF'],
#   ['부르/VV', '시/EP', '었/EP', '어요/EF', '?/SF'],
#   ['아름/NNP',
#    '아/JKV',
#    '일정/NNG',
#    '좀/MAG',
#    '등록/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['원하/VV',
#    '시/EP',
#    '는/ETM',
#    '날짜/NNG',
#    '를/JKO',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['이번/NNG', '달/NNG', '중순/NNG', './SF'],
#   ['장소/NNG',
#    '를/JKO',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['서울/NNP', '식당/NNP', './SF'],
#   ['다시/MAG',
#    '1/SN',
#    '번/NNB',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['서울/NNP', '식당/NNP', '이/VCP', '야/EF', './SF'],
#   ['누구/NP', '와/JKB', '약속/NNG', '이/VCP', '시/EP', '어요/EF', '?/SF'],
#   ['어/IC',
#    '회사/NNG',
#    '친구/NNG',
#    '미연이/NNP',
#    '와/JC',
#    '약속/NNG',
#    '하/XSV',
#    '았/EP',
#    '어/EF',
#    './SF'],
#   ['어떤/MM', '약속/NNG', '이/VCP', '시/EP', '어요/EF', '?/SF'],
#   ['영화/NNG',
#    '관람/NNG',
#    '하/XSV',
#    '기/ETN',
#    '로/JKB',
#    '하/VV',
#    '았/EP',
#    '거든/EF',
#    './SF'],
#   ['다시/MAG',
#    '1/SN',
#    '번/NNB',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['영화/NNG', '관람/NNG', '약속/NNG', '있/VX', '어/EF', './SF'],
#   ['요일/NNP',
#    '을/JKO',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['화요일/NNG', '이/VCP', '야/EF', './SF'],
#   ['시간/NNG',
#    '을/JKO',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['오후/NNG', '1/SN', '시로/NNP', '하/VV', '아/EC', '주/VX', '어/EF', './SF'],
#   ['일정/NNG', '을/JKO', '입력/NNG', '하/XSV', '았/EP', '습니다/EF', './SF'],
#   ['내일/NNG',
#    '아침/NNG',
#    '11/SN',
#    '시/NNB',
#    '에/JKB',
#    '좀/MAG',
#    '깨우/VV',
#    '어/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['알람/NNP', '을/JKO', '설정/NNG', '하/XSV', 'ㅂ니다/EF', './SF'],
#   ['아름/NNP',
#    '아/JKV',
#    '고맙/VA',
#    '어/EC',
#    ',/SP',
#    '잘/MAG',
#    '하/XSV',
#    '았/EP',
#    '어/EF',
#    './SF'],
#   ['아니/VCN', '에요/EF', './SF']],
#  [['아름/NNP', '아/JKV', './SF'],
#   ['부르/VV', '시/EP', '었/EP', '어요/EF', '?/SF'],
#   ['아름/NNP',
#    '아/JKV',
#    '일정/NNG',
#    '등록/NNP',
#    '좀/MAG',
#    '하/VV',
#    '아/EC',
#    '주/VX',
#    '어라/EF',
#    './SF'],
#   ['원하/VV',
#    '시/EP',
#    '는/ETM',
#    '날짜/NNG',
#    '를/JKO',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['오전/NNP', '11/SN', '시야/NNP', './SF'],
#   ['장소/NNG',
#    '를/JKO',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['메가박스/NNP', '영화관/NNP', './SF'],
#   ['누구/NP', '와/JKB', '약속/NNG', '이/VCP', '시/EP', '어요/EF', '?/SF'],
#   ['회사/NNG', '동료/NNG', '영지/NNP', '하고/JKB', '약속/NNG', '이/VCP', '야/EF', './SF'],
#   ['어떤/MM', '약속/NNG', '이/VCP', '시/EP', '어요/EF', '?/SF'],
#   ['어/IC', '선물/NNG', '사/VV', '아야/EC', '되/VV', '거든/EF', './SF'],
#   ['요일/NNP',
#    '을/JKO',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['수요일/NNP', '날/NNG', '할거/NNG', '야/JKV', './SF'],
#   ['시간/NNG',
#    '을/JKO',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['오후/NNG', '2시/NNP', '에/JKB', './SF'],
#   ['일정/NNG', '을/JKO', '입력/NNG', '하/XSV', '았/EP', '습니다/EF', './SF'],
#   ['내일/NNG',
#    '아침/NNG',
#    '7/SN',
#    '시/NNB',
#    '50/SN',
#    '분/NNB',
#    '에/JKB',
#    '깨우/VV',
#    '어/EC',
#    '주/VX',
#    'ㄹ래/EF',
#    '?/SF'],
#   ['알람/NNP', '을/JKO', '설정/NNG', '하/XSV', 'ㅂ니다/EF', './SF'],
#   ['아름/NNP', '아/JKV', '수고/NNG', '하/XSV', '았/EP', '어/EF', './SF'],
#   ['고마워요/NNP', './SF']],
#  [['아름/NNP', '아/JKV', '안녕/IC', '?/SF'],
#   ['안녕하세요/NNP', './SF'],
#   ['아름/NNP',
#    '아/JKV',
#    '일정/NNG',
#    '확인/NNG',
#    '좀/MAG',
#    '하/VV',
#    '아/EC',
#    '주/VX',
#    'ㄹ래/EF',
#    '?/SF'],
#   ['언제/MAG', '일정/NNG', '을/JKO', '확인/NNG', '하/XSV', 'ㄹ까요/EF', '?/SF'],
#   ['주간/NNG', '일정/NNG', './SF'],
#   ['네/IC',
#    ',/SP',
#    '이번/NNG',
#    '주/MM',
#    '오전/NNG',
#    '과/JC',
#    '오후/NNG',
#    '약속/NNG',
#    '이/JKS',
#    '있/VX',
#    '습니다/EF',
#    './SF'],
#   ['음/NNG',
#    '오전/NNP',
#    '약속/NNG',
#    '장소/NNG',
#    '좀/MAG',
#    '알리/VV',
#    '어/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['친구/NNG', '네/XSN', '집/NNG', '이/VCP', 'ㅂ니다/EF', './SF'],
#   ['어/IC',
#    '아름/NNP',
#    '아/JKV',
#    '누구/NP',
#    '하고/JKB',
#    '약속/NNG',
#    '이/VCP',
#    'ㄴ지/EC',
#    '좀/MAG',
#    '알리/VV',
#    '어/EC',
#    '주/VX',
#    'ㄹ래/EF',
#    '?/SF'],
#   ['다시/MAG', '말씀/NNG', '하/XSV', '아/EC', '주/VX', '시/EP', '어요/EF', './SF'],
#   ['아름/NNP',
#    '아/JKV',
#    '누구/NP',
#    '와/JKB',
#    '약속/NNG',
#    '이/VCP',
#    'ㄴ지/EC',
#    '알리/VV',
#    '어/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['고등학교/NNP',
#    '동창/NNP',
#    '분과/NNG',
#    '의/JKG',
#    '약속/NNG',
#    '이/VCP',
#    'ㅂ니다/EF',
#    './SF'],
#   ['약속/NNG', '일정/NNG', '이/JKS', '변경/NNG', '되/XSV', '었/EP', '거든/EF', './SF'],
#   ['어떤/MM', '내용/NNG', '이/JKS', '변경/NNG', '되/XSV', '었/EP', '나요/EF', '?/SF'],
#   ['음/NNG', '날짜/NNP', '가/JKS', '바/NNB', '끼/VV', '었/EP', '어/EF', './SF'],
#   ['바뀌/VV',
#    'ㄴ/ETM',
#    '날짜/NNG',
#    '를/JKO',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['10월', '2일/NNP', '로/JKB', '변경/NNG', '되/XSV', '었/EP', '어/EF', './SF'],
#   ['시간/NNG', '도/JX', '변경/NNG', '되/XSV', '었/EP', '나요/EF', '?/SF'],
#   ['아니/IC',
#    ',/SP',
#    '시간/NNG',
#    '은/JX',
#    '변경/NNG',
#    '되/XSV',
#    '지/EC',
#    '않/VX',
#    '았/EP',
#    '고/EF',
#    './SF'],
#   ['약속/NNG', '장소/NNG', '는/JX', '어디/NP', '세/VA', '요/EF', '?/SF'],
#   ['메가박스/NNP', '영화관/NNP', './SF'],
#   ['일정/NNG', '을/JKO', '변경/NNG', '하/XSV', '았/EP', '습니다/EF', './SF'],
#   ['아름/NNP', '아/JKV', '고맙/VA', '어/EF', './SF'],
#   ['아니/VCN', '에요/EF', './SF']],
#  [['아름/NNP', '아/JKV'],
#   ['부르/VV', '시/EP', '었/EP', '어요/EF', './SF'],
#   ['아름/NNP',
#    '아/JKV',
#    '일정/NNG',
#    '등록/NNP',
#    '좀/MAG',
#    '하/VV',
#    '아/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['원하/VV',
#    '시/EP',
#    '는/ETM',
#    '날짜/NNG',
#    '를/JKO',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['모레/NNG', '오후/NNG', './SF'],
#   ['장소/NNG',
#    '를/JKO',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['메가박스/NNP', '영화관/NNP', './SF'],
#   ['누구/NP', '와/JKB', '약속/NNG', '이/VCP', '시/EP', '어요/EF', '?/SF'],
#   ['친척/NNG', '모임/NNG', './SF'],
#   ['어떤/MM', '약속/NNG', '이/VCP', '시/EP', '어요/EF', '?/SF'],
#   ['백화점/NNP', '쇼핑/NNP', '할거/NNG', '야/JKV', './SF'],
#   ['요일/NNP',
#    '을/JKO',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['수요일/NNP', './SF'],
#   ['시간/NNG',
#    '을/JKO',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['오후/NNG', '2시/NNP', './SF'],
#   ['일정/NNG', '을/JKO', '입력/NNG', '하/XSV', '았/EP', '습니다/EF', './SF'],
#   ['내일/NNG',
#    '아침/NNG',
#    '7/SN',
#    '시/NNB',
#    '30/SN',
#    '분/NNB',
#    '에/JKB',
#    '깨우/VV',
#    '어/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['알람/NNP', '을/JKO', '설정/NNG', '하/XSV', 'ㅂ니다/EF', './SF'],
#   ['아름/NNP', '아/JKV', '고맙/VA', '어/EF', './SF'],
#   ['아니/VCN', '에요/EF', './SF']],
#  [['아름/NNP', '아/JKV', './SF'],
#   ['부르/VV', '시/EP', '었/EP', '어요/EF', './SF'],
#   ['아름/NNP',
#    '아/JKV',
#    '일정/NNG',
#    '등록/NNP',
#    '좀/MAG',
#    '하/VV',
#    '아/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['원하/VV',
#    '시/EP',
#    '는/ETM',
#    '날짜/NNG',
#    '를/JKO',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['이번/NNG', '달/NNG', '말로/NNP', './SF'],
#   ['장소/NNG',
#    '를/JKO',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['삼/NR', '오/NNP', '식당/NNP', './SF'],
#   ['누구/NP', '와/JKB', '약속/NNG', '이/VCP', '시/EP', '어요/EF', '?/SF'],
#   ['회사/NNG',
#    '동료/NNG',
#    '장지영/NNP',
#    '과/JC',
#    '약속/NNG',
#    '이/VCP',
#    '라고/EC',
#    '하/VV',
#    '아/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['어떤/MM', '약속/NNG', '이/VCP', '시/EP', '어요/EF', '?/SF'],
#   ['백화점/NNP', '쇼핑/NNG', '이/VCP', '야/EF', './SF'],
#   ['요일/NNP',
#    '을/JKO',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['화요일/NNG', '이/VCP', '고/EF', './SF'],
#   ['시간/NNG',
#    '을/JKO',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['오후/NNG', '1/SN', '시야/NNP', './SF'],
#   ['일정/NNG', '을/JKO', '입력/NNG', '하/XSV', '았/EP', '습니다/EF', './SF'],
#   ['내일/NNG',
#    '아침/NNG',
#    '7/SN',
#    '시/NNB',
#    '에/JKB',
#    '깨우/VV',
#    '어/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['알람/NNP', '을/JKO', '설정/NNG', '하/XSV', 'ㅂ니다/EF', './SF'],
#   ['아름/NNP', '아/JKV', '수고/NNG', '하/XSV', '았/EP', '어/EF', './SF'],
#   ['고맙/VA', '아요/EF', './SF']],
#  [['아름/NNP', '아/JKV', '반갑/VA', '어/EF', './SF'],
#   ['저/NP', '도/JX', '반갑/VA', '어요/EF', './SF'],
#   ['아름/NNP',
#    '아/JKV',
#    '일정/NNG',
#    '확인/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    'ㄹ/ETM',
#    '수/NNB',
#    '있/VX',
#    '니/EF',
#    '?/SF'],
#   ['네/IC',
#    ',/SP',
#    '언제/MAG',
#    '일정/NNG',
#    '을/JKO',
#    '확인/NNG',
#    '하/XSV',
#    'ㄹ까요/EF',
#    '?/SF'],
#   ['이번/NNG',
#    '달/NNG',
#    '일정/NNG',
#    '좀/MAG',
#    '알리/VV',
#    '어/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['네/IC',
#    ',/SP',
#    '오전/NNG',
#    '과/JC',
#    '오후/NNG',
#    '약속/NNG',
#    '이/JKS',
#    '있/VX',
#    '습니다/EF',
#    './SF'],
#   ['오후/NNG',
#    '약속/NNG',
#    '장소/NNG',
#    '를/JKO',
#    '알리/VV',
#    '어/EC',
#    '주/VX',
#    'ㄹ/ETM',
#    '수/NNB',
#    '있/VX',
#    '니/EF',
#    '?/SF'],
#   ['약속/NNG', '장소/NNG', '는/JX', '롯데백화점/NNP', '이/VCP', '에요/EF', './SF'],
#   ['아름/NNP',
#    '아/JKV',
#    '어/IC',
#    '누구/NP',
#    '와/JKB',
#    '약속/NNG',
#    '이/VCP',
#    'ㄴ지/EC',
#    '좀/MAG',
#    '보아주/VV',
#    'ㄹ래/EF',
#    '?/SF'],
#   ['네/IC',
#    ',/SP',
#    '대학/NNG',
#    '동기/NNG',
#    '와/JKB',
#    '의/JKG',
#    '약속/NNG',
#    '이/VCP',
#    'ㅂ니다/EF',
#    './SF'],
#   ['음/NNG',
#    '약속/NNG',
#    '일정/NNG',
#    '이/JKS',
#    '변경/NNG',
#    '되/XSV',
#    '었/EP',
#    '어/EF',
#    './SF'],
#   ['무슨/MM', '내용/NNG', '이/JKS', '변경/NNG', '되/XSV', '었/EP', '나요/EF', '?/SF'],
#   ['어/IC', '약속/NNG', '날짜/NNP', '가/JKS', '바뀌/VV', '었/EP', '거든/EF', './SF'],
#   ['언제/NP', '로/JKB', '바뀌/VV', '었/EP', '나요/EF', './SF'],
#   ['어/IC', '7월', '1일/NNP', '로/JKB', '변경/NNG', '되/XSV', '었/EP', '어/EF', './SF'],
#   ['시간/NNG', '도/JX', '변경/NNG', '되/XSV', '었/EP', '나요/EF', '?/SF'],
#   ['아니야/NNP',
#    ',/SP',
#    '시간/NNG',
#    '은/JX',
#    '같/VA',
#    '은/ETM',
#    '시간/NNG',
#    '이/VCP',
#    '야/EF',
#    './SF'],
#   ['네/IC', ',/SP', '장소/NNG', '는/JX', '어디/NP', '세/VA', '요/EF', '?/SF'],
#   ['장소/NNG', '는/JX', '현대백화점/NNP', '이/VCP', '거든/EF', './SF'],
#   ['일정/NNG', '을/JKO', '변경/NNG', '하/XSV', 'ㅂ니다/EF', './SF'],
#   ['어/IC', '그러/VV', '어/EC', '아름/NNP', '아/JKV', '고맙/VA', '어/EF', './SF'],
#   ['또/MAJ', '부르/VV', '어/EC', '주/VX', '시/EP', '어요/EF', './SF']],
#  [['아름/NNP', '아/JKV', './SF'],
#   ['부르/VV', '시/EP', '었/EP', '어요/EF', './SF'],
#   ['일정/NNG', '등록/NNP', '좀/MAG', '하/VV', '아/EC', '주/VX', 'ㄹ래/EF', '?/SF'],
#   ['원하/VV',
#    '시/EP',
#    '는/ETM',
#    '날짜/NNG',
#    '를/JKO',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['오후/NNG', '5/SN', '시/NNB', './SF'],
#   ['장소/NNG',
#    '를/JKO',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['강변/NNG', '식당/NNG', '에서/JKB', './SF'],
#   ['누구/NP', '와/JKB', '약속/NNG', '이/VCP', '시/EP', '어요/EF', '?/SF'],
#   ['친구/NNG', '미연/NNG', '이랑/NNP', '약속/NNG', '있/VV', '어/EF', './SF'],
#   ['어떤/MM', '약속/NNG', '이/VCP', '시/EP', '어요/EF', '?/SF'],
#   ['홈/NNG', '마트/NNP', '에서/JKB', '쇼핑/NNG', '하/XSV', 'ㄴ다고/EF', './SF'],
#   ['요일/NNP',
#    '을/JKO',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['화요일/NNP', '에/JKB', './SF'],
#   ['시간/NNG',
#    '을/JKO',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['오후/NNG', '1/SN', '시/NNB', './SF'],
#   ['일정/NNG', '을/JKO', '입력/NNG', '하/XSV', 'ㅂ니다/EF', './SF'],
#   ['내일/NNG',
#    '아침/NNG',
#    '10/SN',
#    '시/NNB',
#    '에/JKB',
#    '깨우/VV',
#    '어/EC',
#    '주/VX',
#    'ㄹ래/EF',
#    '?/SF'],
#   ['알/VV', '겠/EP', '습니다/EF', './SF'],
#   ['아름/NNP', '아/JKV', '수고/NNG', '하/XSV', '았/EP', '어/EF', './SF'],
#   ['고마워요/NNP', './SF']],
#  [['아름/NNP', '아/JKV', '안녕/IC', './SF'],
#   ['안녕하세요/NNP', './SF'],
#   ['아름/NNP', '아/JKV', '거실/NNP', '로/JKB', '좀/MAG', '오/VX', 'ㄹ래/EF', '?/SF'],
#   ['네/IC', ',/SP', '부르/VV', '시/EP', '었/EP', '어요/EF', './SF'],
#   ['스케줄/NNP',
#    '을/JKO',
#    '좀/MAG',
#    '정리/NNG',
#    '하/XSV',
#    '려고/EC',
#    '하/VV',
#    '는데/EC',
#    '도와주/VV',
#    '겠/EP',
#    '니/EF',
#    '?/SF'],
#   ['네/IC', ',/SP', '돕/VV', '아/EC', '드리/VX', 'ㄹ게요/EF', './SF'],
#   ['내일/NNG',
#    '스케줄/NNP',
#    '을/JKO',
#    '좀/MAG',
#    '검색/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '겠/EP',
#    '니/EF',
#    '?/SF'],
#   ['네/IC',
#    ',/SP',
#    '내일/NNG',
#    '7/SN',
#    '시/NNB',
#    '에/JKB',
#    '동창/NNP',
#    '모임/NNG',
#    '이/JKS',
#    '있/VX',
#    '어요/EF',
#    './SF'],
#   ['내일/NNG',
#    '저녁/NNG',
#    '7/SN',
#    '시/NNB',
#    '약속/NNG',
#    '은/JX',
#    '취소/NNG',
#    '되/XSV',
#    '었/EP',
#    '거든/EF',
#    './SF'],
#   ['네/IC',
#    ',/SP',
#    '그렇/VA',
#    '군요/EF',
#    './SF',
#    '그럼/MAJ',
#    '삭제/NNG',
#    '하/XSV',
#    '아/EC',
#    '드리/VX',
#    'ㄹ까요/EF',
#    '?/SF'],
#   ['응/IC',
#    ',/SP',
#    '그/MM',
#    '약속/NNG',
#    '을/JKO',
#    '삭제/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['네/IC', ',/SP', '삭제/NNG', '되/XSV', '었/EP', '습니다/EF', './SF'],
#   ['알람/NNP',
#    '이/JKS',
#    '되/VV',
#    '어/EC',
#    '있/VX',
#    '는지/EC',
#    '확인/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '겠/EP',
#    '니/EF',
#    '?/SF'],
#   ['네/IC',
#    ',/SP',
#    '3/SN',
#    '시간/NNP',
#    '전/NNG',
#    '에/JKB',
#    '알람/NNP',
#    '이/JKS',
#    '설정/NNG',
#    '되/XSV',
#    '어/EC',
#    '있/VX',
#    '어요/EF',
#    './SF'],
#   ['알람/NNP',
#    '도/JX',
#    '삭제/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '겠/EP',
#    '어/EF',
#    '?/SF'],
#   ['네/IC', ',/SP', '삭제/NNG', '하/XSV', 'ㅂ니다/EF', './SF'],
#   ['이번/NNG',
#    '주말/NNP',
#    '에/JKB',
#    '저녁/NNG',
#    '약속/NNG',
#    '스케줄/NNP',
#    '이/JKS',
#    '있/VV',
#    '는지/EC',
#    '확인/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '겠/EP',
#    '니/EF',
#    '?/SF'],
#   ['네/IC',
#    ',/SP',
#    '친구/NNG',
#    '분/XSN',
#    '과/JC',
#    '약속/NNG',
#    '이/JKS',
#    '있/VX',
#    '어요/EF',
#    './SF'],
#   ['시간/NNG', '이/JKS', '몇/MM', '시지/NNP', '?/SF'],
#   ['저녁/NNG', '6/SN', '시/NNB', '반/NNG', '이/VCP', '에요/EF', './SF'],
#   ['시간/NNG',
#    '을/JKO',
#    '30/SN',
#    '분/NNB',
#    '만/JX',
#    '당기/VV',
#    '어/EC',
#    '주/VX',
#    '겠/EP',
#    '어/EF',
#    '?/SF'],
#   ['네/IC', ',/SP', '알/VV', '겠/EP', '습니다/EF', './SF'],
#   ['고맙/VA', '어/EC', ',/SP', '부탁/NNG', '들/VV', '어/EC', '주/VX', '어서/EF', './SF'],
#   ['아니/VCN', '에요/EF', './SF']],
#  [['아름/NNP', '아/JKV', '반갑/VA', '어/EF', './SF'],
#   ['네/IC', ',/SP', '안녕하세요/NNP', './SF'],
#   ['오늘/NNG',
#    '일정/NNG',
#    '을/JKO',
#    '좀/MAG',
#    '검색/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '겠/EP',
#    '니/EF',
#    '?/SF'],
#   ['네/IC',
#    ',/SP',
#    '점심/NNG',
#    '에/JKB',
#    '식사/NNG',
#    '약속/NNG',
#    '이/JKS',
#    '있/VX',
#    '습니다/EF',
#    './SF'],
#   ['알람/NNP', '은/JX', '설정/NNG', '되/XSV', '어/EC', '있/VX', '어/EF', '?/SF'],
#   ['네/IC', ',/SP', '설정/NNG', '되/XSV', '어/EC', '있/VX', '어요/EF', './SF'],
#   ['점심때/NNG',
#    '있/VV',
#    '는/ETM',
#    '식사/NNG',
#    '약속/NNG',
#    '을/JKO',
#    '좀/MAG',
#    '취소/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['네/IC', ',/SP', '취소/NNG', '하/XSV', 'ㅂ니다/EF', './SF'],
#   ['내일/NNG', '의/JKG', '일정/NNG', '은/JX', '뭐/NP', '야/JKV', '?/SF'],
#   ['내일/NNG', '은/JX', '일정/NNG', '이/JKS', '없/VA', '어요/EF', './SF'],
#   ['내일/NNG',
#    '오후/NNG',
#    '6/SN',
#    '시/NNB',
#    '반/NNG',
#    '으로/JKB',
#    '식사/NNP',
#    '약속/NNP',
#    '1/SN',
#    '만/NR',
#    '변경/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '겠/EP',
#    '니/EF',
#    '?/SF'],
#   ['네/IC', ',/SP', '변경/NNG', '하/XSV', 'ㅂ니다/EF', './SF'],
#   ['내일/NNG',
#    '아침/NNG',
#    '10/SN',
#    '시로/NNP',
#    '알람/NNP',
#    '을/JKO',
#    '설정/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['알람/NNP', '을/JKO', '설정/NNG', '하/XSV', 'ㅂ니다/EF', './SF'],
#   ['알람/NNP',
#    '이/JKS',
#    '맞/VV',
#    '게/EC',
#    '설정/NNG',
#    '되/XSV',
#    '어/EC',
#    '있/VX',
#    '어/EF',
#    '?/SF'],
#   ['네/IC', ',/SP', '확인/NNG', '되/XSV', '었/EP', '어요/EF', './SF'],
#   ['오늘/NNG',
#    '은/JX',
#    '운동/NNG',
#    '을/JKO',
#    '가/VV',
#    'ㄹ테니까/EC',
#    '새롭/VA',
#    'ㄴ/ETM',
#    '일정/NNG',
#    '을/JKO',
#    '입력/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['알/VV',
#    '겠/EP',
#    '습니다/EF',
#    './SF',
#    '몇/MM',
#    '시/NNB',
#    '에/JKB',
#    '일정/NNG',
#    '을/JKO',
#    '입력/NNG',
#    '하/XSV',
#    'ㄹ까요/EF',
#    '?/SF'],
#   ['6/SN', '시/NNB', '에/JKB', '출발/NNG', '할거/NNG', '야/JKV', './SF'],
#   ['입력/NNG', '되/XSV', '었/EP', '어요/EF', './SF'],
#   ['고맙/VA', '어/EF', './SF'],
#   ['아니/VCN', '에요/EF', './SF']],
#  [['아름/NNP', '아/JKV', '안녕/IC', './SF'],
#   ['안녕하세요/NNP', './SF'],
#   ['어/IC',
#    '일정/NNG',
#    '확인/NNG',
#    '좀/MAG',
#    '하/VV',
#    '아/EC',
#    '주/VX',
#    'ㄹ래/EF',
#    '?/SF'],
#   ['네/IC',
#    ',/SP',
#    '언제/MAG',
#    '일정/NNG',
#    '을/JKO',
#    '확인/NNG',
#    '하/XSV',
#    'ㄹ까요/EF',
#    '?/SF'],
#   ['어/IC',
#    '다음/NNG',
#    '주/NNP',
#    '일정/NNG',
#    '좀/MAG',
#    '알리/VV',
#    '어/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['일정/NNG',
#    '을/JKO',
#    '검색/NNG',
#    '하/XSV',
#    'ㅂ니다/EF',
#    './SF',
#    '오전/NNG',
#    '과/JC',
#    '오후/NNG',
#    '약속/NNG',
#    '이/JKS',
#    '있/VX',
#    '습니다/EF',
#    './SF'],
#   ['음/NNG', '오전/NNP', '약속/NNG', '일정/NNG', './SF'],
#   ['다시/MAG', '말씀/NNG', '하/XSV', '아/EC', '주/VX', '시/EP', '어요/EF', './SF'],
#   ['오전/NNP',
#    '약속/NNG',
#    '장소/NNG',
#    '좀/MAG',
#    '알리/VV',
#    '어/EC',
#    '주/VX',
#    'ㄹ래/EF',
#    '?/SF'],
#   ['네/IC',
#    ',/SP',
#    '약속/NNG',
#    '장소/NNG',
#    '는/JX',
#    '교보문고/NNP',
#    '이/VCP',
#    'ㅂ니다/EF',
#    './SF'],
#   ['어/IC',
#    '내/NP',
#    '가/JKS',
#    '누구/NP',
#    '와/JKB',
#    '약속/NNG',
#    '을/JKO',
#    '하/VV',
#    '았/EP',
#    '지/EF',
#    '?/SF'],
#   ['초등학교/NNP',
#    '동창/NNP',
#    '분과/NNG',
#    '의/JKG',
#    '약속/NNG',
#    '이/VCP',
#    '에요/EF',
#    './SF'],
#   ['어/IC',
#    '약속/NNG',
#    '일정/NNG',
#    '이/JKS',
#    '변경/NNG',
#    '되/XSV',
#    '었/EP',
#    '는데/EF',
#    './SF'],
#   ['네/IC',
#    ',/SP',
#    '어떤/MM',
#    '내용/NNG',
#    '이/JKS',
#    '변경/NNG',
#    '되/XSV',
#    '었/EP',
#    '나요/EF',
#    '?/SF'],
#   ['어/IC',
#    '나/NP',
#    '약속/NNG',
#    '날짜/NNP',
#    '가/JKS',
#    '바꾸/VV',
#    '었/EP',
#    '어/EF',
#    './SF'],
#   ['다시/MAG', '말씀/NNG', '하/XSV', '아/EC', '주/VX', '시/EP', '어요/EF', './SF'],
#   ['약속/NNG', '날짜/NNP', '가/JKS', '바뀌/VV', '었/EP', '어/EF', './SF'],
#   ['바뀌/VV',
#    'ㄴ/ETM',
#    '날짜/NNG',
#    '를/JKO',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['어/IC',
#    '10월',
#    '3일/NNP',
#    '로/JKB',
#    '변경/NNG',
#    '되/XSV',
#    '었/EP',
#    '어/EF',
#    './SF'],
#   ['네/IC',
#    ',/SP',
#    '알/VV',
#    '겠/EP',
#    '습니다/EF',
#    './SF',
#    '시간/NNG',
#    '도/JX',
#    '변경/NNG',
#    '되/XSV',
#    '었/EP',
#    '나요/EF',
#    '?/SF'],
#   ['아니/IC', ',/SP', '같/VA', '은/ETM', '시간/NNG', '이/VCP', '야/EF', './SF'],
#   ['약속/NNG', '장소/NNG', '는/JX', '어디/NP', '세/VA', '요/EF', '?/SF'],
#   ['어/IC', '메가박스/NNP', '영화관/NNP', './SF'],
#   ['네/IC',
#    ',/SP',
#    '일정/NNG',
#    '을/JKO',
#    '변경/NNG',
#    '하/XSV',
#    '았/EP',
#    '습니다/EF',
#    './SF'],
#   ['음/NNG', '아름/NNP', '아/JKV', '고맙/VA', '다/EF', './SF'],
#   ['또/MAJ', '부르/VV', '어/EC', '주/VX', '시/EP', '어요/EF', './SF']],
#  [['아름/NNP', '아/JKV', '반갑/VA', '어/EF', './SF'],
#   ['반갑/VA', '어요/EF', './SF'],
#   ['아름/NNP', '아/JKV', '서재/NNP', '로/JKB', '오/VX', '아라/EF', './SF'],
#   ['부르/VV', '시/EP', '었/EP', '어요/EF', './SF'],
#   ['아름/NNP',
#    '아/JKV',
#    '오늘/NNG',
#    '일정/NNG',
#    '이/JKS',
#    '어떻/VA',
#    '게/EC',
#    '되/VV',
#    '니/EF',
#    '?/SF'],
#   ['저녁/NNG',
#    '에/JKB',
#    '가족/NNG',
#    '식사/NNP',
#    '모임/NNG',
#    '이/JKS',
#    '있/VX',
#    '습니다/EF',
#    './SF'],
#   ['오늘/NNG',
#    '일정/NNG',
#    '에/JKB',
#    '없/VA',
#    '는/ETM',
#    '회식/NNG',
#    '을/JKO',
#    '하/VV',
#    '게/EC',
#    '되/VV',
#    '었/EP',
#    '거든/EF',
#    './SF'],
#   ['네/IC', ',/SP', '그렇/VA', '군요/EF', './SF'],
#   ['저녁/NNG',
#    '에/JKB',
#    '가족/NNG',
#    '모임/NNP',
#    '가족/NNG',
#    '식사/NNP',
#    '모임/NNG',
#    '은/JX',
#    '취소/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    'ㄹ래/EF',
#    '?/SF'],
#   ['다시/MAG',
#    '1/SN',
#    '번/NNB',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['저녁/NNG',
#    '가족/NNG',
#    '식사/NNP',
#    '모임/NNG',
#    '은/JX',
#    '취소/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['취소/NNG', '하/XSV', 'ㅂ니다/EF', './SF'],
#   ['회식/NNG',
#    '일정/NNG',
#    '을/JKO',
#    '등록/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    'ㄹ래/EF',
#    '?/SF'],
#   ['일정/NNG', '을/JKO', '등록/NNG', '하/XSV', 'ㅂ니다/EF', './SF'],
#   ['가족/NNG',
#    '식사/NNP',
#    '모임/NNG',
#    '은/JX',
#    '내일/NNG',
#    '저녁/NNG',
#    '에/JKB',
#    '하/VX',
#    'ㄹ게/EF',
#    './SF'],
#   ['일정/NNG', '을/JKO', '변경/NNG', '하/XSV', 'ㅂ니다/EF', './SF'],
#   ['늦/VA',
#    '지/EC',
#    '않/VX',
#    '게/EC',
#    '알람/NNP',
#    '을/JKO',
#    '설정/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['몇/MM', '시로/NNP', '설정/NNG', '하/XSV', 'ㄹ까요/EF', '?/SF'],
#   ['오후/NNG',
#    '6/SN',
#    '시로/NNP',
#    '설정/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['설정/NNG', '하/XSV', 'ㅂ니다/EF', './SF'],
#   ['아름/NNP', '아/JKV', '고맙/VA', '어/EF', './SF'],
#   ['아니/VCN', '에요/EF', './SF']],
#  [['아름/NNP', '아/JKV', '안녕/IC', './SF'],
#   ['안녕하세요/NNP', './SF'],
#   ['할아버지/NNG', '생신/NNG', '이/JKS', '언제/NP', '지/EF', '?/SF'],
#   ['이번/NNG', '주/MM', '토요일/NNG', '이/VCP', '에요/EF', './SF'],
#   ['토요일/NNP',
#    '날/NNG',
#    '일정/NNG',
#    '을/JKO',
#    '확인/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['특별/XR', '하/XSA', 'ㄴ/ETM', '일정/NNG', '이/JKS', '없/VA', '습니다/EF', './SF'],
#   ['그럼/MAJ',
#    '할아버지/NNG',
#    '생신/NNG',
#    '에/JKB',
#    '가/VV',
#    'ㄴ다고/EC',
#    '하/VX',
#    '아/EF',
#    './SF'],
#   ['입력/NNG', '하/XSV', 'ㅂ니다/EF', './SF'],
#   ['이번/NNG',
#    '주/MM',
#    '토요일/NNP',
#    '아침/NNG',
#    '9/SN',
#    '시/NNB',
#    '에/JKB',
#    '알람/NNP',
#    '을/JKO',
#    '설정/NNG',
#    '하/XSV',
#    '아/EF',
#    './SF'],
#   ['알람/NNP', '을/JKO', '설정/NNG', '하/XSV', 'ㅂ니다/EF', './SF'],
#   ['이번/NNG',
#    '주/MM',
#    '토요일/NNG',
#    '에/JKB',
#    '다른/MM',
#    '일정/NNG',
#    '이/JKS',
#    '있/VX',
#    '니/EF',
#    '?/SF'],
#   ['저녁/NNG',
#    '에/JKB',
#    '친구/NNG',
#    '와/JC',
#    '산책/NNG',
#    '을/JKO',
#    '하/VX',
#    'ㄴ다/EF',
#    './SF',
#    "'/SS",
#    '이/VCP',
#    'ㅂ니다/EF',
#    './SF'],
#   ['취소/NNG', '하/XSV', '아/EC', '주/VX', '어/EF', './SF'],
#   ['취소/NNG', '하/XSV', 'ㅂ니다/EF', './SF'],
#   ['오늘/NNG', '일정/NNG', '은/JX', '어떻/VA', '게/EC', '되/VV', '어/EF', '?/SF'],
#   ['오늘/NNG',
#    '은/JX',
#    "'/SS",
#    '쇼핑/NNP',
#    '가/VV',
#    '기/ETN',
#    './SF',
#    "'/SS",
#    '에요/EF',
#    './SF'],
#   ['쇼핑/NNP', '은/JX', '내일/NNG', '갈/VV', '게/EF', './SF'],
#   ['내일/NNG', '은/JX', '일정/NNG', '이/JKS', '있/VX', '습니다/EF', './SF'],
#   ['그럼/MAJ', '모레/NNG', '로/JKB', '미루/VV', 'ㄹ게/EF', './SF'],
#   ['알/VV', '겠/EP', '습니다/EF', './SF'],
#   ['아름/NNP', '아/JKV', '고맙/VA', '어/EF', './SF'],
#   ['아니/VCN', '에요/EF', './SF']],
#  [['아름/NNP', '아/JKV', '안녕/IC', './SF'],
#   ['안녕하세요/NNP', './SF'],
#   ['어/IC',
#    '아름/NNP',
#    '아/JKV',
#    '이리/MAG',
#    '좀/MAG',
#    '오/VV',
#    '아/EC',
#    '보/VX',
#    '아/EF',
#    './SF'],
#   ['네/IC', ',/SP', '저/MM', '오/VX', '았/EP', '어요/EF', './SF'],
#   ['음/NNG', '아름/NNP', '아/JKV', '안녕/IC', './SF'],
#   ['네/IC', './SF'],
#   ['아/IC',
#    '오늘/NNG',
#    '오후/NNG',
#    '에/JKB',
#    '뭐/NP',
#    '하/VV',
#    'ㄹ려고/EC',
#    '하/VV',
#    '았/EP',
#    '더라/EF',
#    '?/SF'],
#   ['잠시/NNG',
#    '만요/NNP',
#    './SF',
#    '오늘/NNG',
#    '오후/NNG',
#    '소풍/NNG',
#    '을/JKO',
#    '가/VV',
#    '기/ETN',
#    '로/JKB',
#    '하/VV',
#    '시/EP',
#    '었/EP',
#    '어요/EF',
#    './SF'],
#   ['아/IC',
#    '그렇/VA',
#    '구나/EC',
#    ',/SP',
#    '그럼/MAJ',
#    '3/SN',
#    '시/NNB',
#    '에/JKB',
#    '알람/NNP',
#    '좀/MAG',
#    '맞추/VV',
#    '어/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['네/IC', ',/SP', '설정/NNG', '하/XSV', '았/EP', '습니다/EF', './SF'],
#   ['음/NNG',
#    '알람/NNP',
#    '이/JKS',
#    '맞/VV',
#    '게/EC',
#    '설정/NNG',
#    '되/XSV',
#    '었/EP',
#    '나/EF',
#    '?/SF'],
#   ['네/IC', ',/SP', '설정/NNG', '되/XSV', '었/EP', '어요/EF', './SF'],
#   ['어/IC',
#    '내일/NNG',
#    '은/JX',
#    '뭐/NNG',
#    '하/XSV',
#    '려고/EC',
#    '하/VV',
#    '았/EP',
#    '더라/EF',
#    '?/SF'],
#   ['내일/NNG',
#    '은/JX',
#    '친구/NNG',
#    '와/JC',
#    '영화/NNG',
#    '보기/NNP',
#    '로/JKB',
#    '하/VV',
#    '시/EP',
#    '었/EP',
#    '어요/EF',
#    './SF'],
#   ['몇/MM',
#    '시/NNB',
#    '에/JKB',
#    '보/VV',
#    '기/ETN',
#    '로/JKB',
#    '하/VV',
#    '았/EP',
#    '는데/EF',
#    '?/SF'],
#   ['네/IC', ',/SP', '3/SN', '시/NNB', '이/VCP', 'ㅂ니다/EF', './SF'],
#   ['어/IC',
#    '아이/NNG',
#    '그때/NNG',
#    '안/NNG',
#    '되/XSV',
#    '는데/EC',
#    '그것/NP',
#    '좀/MAG',
#    '고치/VV',
#    '어야/EC',
#    '하/VX',
#    '겠/EP',
#    '다/EF',
#    './SF'],
#   ['몇/MM', '시로/NNP', '수정/NNG', '하/XSV', 'ㄹ까요/EF', '?/SF'],
#   ['어/IC', '한/MM', '2/SN', '시간/NNP', '후/NNG', './SF'],
#   ['알/VV', '겠/EP', '습니다/EF', './SF'],
#   ['아/IC', '고맙/VA', '어/EF', './SF'],
#   ['아니/VCN', '에요/EF', './SF']],
#  [['아름/NNP', '아/JKV', '안녕/IC', './SF'],
#   ['안녕하세요/NNP', './SF'],
#   ['어/IC',
#    '우철/NNP',
#    '이/NNP',
#    '가/JKS',
#    '병원/NNG',
#    '에/JKB',
#    '입원/NNG',
#    '하/XSV',
#    'ㄴ/ETM',
#    '날/NNG',
#    '이/JKS',
#    '언제/NP',
#    '지/EF',
#    '?/SF'],
#   ['네/IC',
#    ',/SP',
#    '잠시/NNG',
#    '만요/NNP',
#    './SF',
#    '7월',
#    '13일/NNP',
#    '이/VCP',
#    'ㅂ니다/EF',
#    './SF'],
#   ['아이/NNG', '왜/MAG', '입원/NNG', '하/XSV', '았/EP', '더라/EF', './SF'],
#   ['네/IC', './SF', '맹장/NNP', '이/VCP', '에요/EF', './SF'],
#   ['아유/IC', '언제/MAG', '퇴원/NNG', '하/XSV', '니/EF', '?/SF'],
#   ['다음/NNG',
#    '주/MM',
#    '내/NP',
#    '로/JKB',
#    '퇴원/NNG',
#    '하/XSV',
#    'ㄹ/ETM',
#    '것/NNB',
#    '같/VA',
#    '아요/EF',
#    './SF'],
#   ['음/NNG',
#    '아니/IC',
#    ',/SP',
#    '엄마/NNG',
#    '이번/NNG',
#    '달/NNG',
#    '연수/NNP',
#    '일/NNP',
#    '이/JKS',
#    '언제/NP',
#    '야/JKV',
#    '?/SF'],
#   ['확인/NNG',
#    '중/NNB',
#    '이/VCP',
#    'ㅂ니다/EF',
#    './SF',
#    '7월',
#    '28일/NNP',
#    '이/VCP',
#    '에요/EF',
#    './SF'],
#   ['어/IC',
#    '기간/NNG',
#    '은/JX',
#    '한/MM',
#    '며칠/NNG',
#    '정도/NNG',
#    '되/VV',
#    '어/EF',
#    '?/SF'],
#   ['2/SN', '박/NNP', '3/SN', '일/NNB', '이/VCP', 'ㅂ니다/EF', './SF'],
#   ['어/IC',
#    '열/VV',
#    'ㄴ/ETM',
#    '수지/NNP',
#    '는/JX',
#    '어디/NP',
#    '이/VCP',
#    '니/EF',
#    '?/SF'],
#   ['네/IC', ',/SP', '안산/NNP', '이/VCP', 'ㅂ니다/EF', './SF'],
#   ['아/IC',
#    '그럼/MAJ',
#    '내일/NNG',
#    '일정/NNG',
#    '좀/MAG',
#    '검색/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['네/IC',
#    ',/SP',
#    '검색/NNG',
#    '하/XSV',
#    'ㅂ니다/EF',
#    './SF',
#    '일정/NNG',
#    '이/JKS',
#    '없/VA',
#    '습니다/EF',
#    './SF'],
#   ['음/NNG',
#    '그럼/MAJ',
#    '내일/NNG',
#    '일정/NNG',
#    '좀/MAG',
#    '입력/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['네/IC', ',/SP', '말씀/NNG', '하/XSV', '시/EP', '어요/EF', './SF'],
#   ['어/IC',
#    "'/SS",
#    '이마트/NNP',
#    '다녀오/VV',
#    '기/ETN',
#    "'/SS",
#    '라고/JKQ',
#    '입력/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    'ㄹ래/EF',
#    '?/SF'],
#   ['네/IC', ',/SP', '입력/NNG', '되/XSV', '었/EP', '어요/EF', './SF'],
#   ['어/IC',
#    '제대로/MAG',
#    '입력/NNG',
#    '되/XSV',
#    '었/EP',
#    '는지/EC',
#    '다시/MAG',
#    '1/SN',
#    '번/NNB',
#    '확인/NNG',
#    '좀/MAG',
#    '하/VV',
#    '아/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['네/IC',
#    ',/SP',
#    '내일/NNG',
#    "'/SS",
#    '이마트/NNP',
#    '다녀오/VV',
#    '기/ETN',
#    "'/SS",
#    '가/JKS',
#    '입력/NNG',
#    '되/XSV',
#    '었/EP',
#    '습니다/EF',
#    './SF'],
#   ['음/NNG', '고맙/VA', '어/EC', ',/SP', '아름/NNP', '아/JKV', './SF'],
#   ['좋/VA', '은/ETM', '1/SN', '일/NNB', '되/VV', '시/EP', '어요/EF', './SF']],
#  [['아름/NNP',
#    '아/JKV',
#    '일정/NNG',
#    '등록/NNG',
#    '을/JKO',
#    '하/VV',
#    '아/EC',
#    '주/VX',
#    'ㄹ래/EF',
#    '?/SF'],
#   ['원하/VV',
#    '는/ETM',
#    '날짜/NNG',
#    '를/JKO',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['오후/NNG', '5/SN', '시야/NNP', './SF'],
#   ['장소/NNG', '를/JKO', '말씀/NNG', '하/XSV', '시/EP', '어요/EF', './SF'],
#   ['맛나/NNP', '식당/NNP', '이/VCP', '야/EF', './SF'],
#   ['누구/NP', '와/JKB', '약속/NNG', '이/VCP', '시/EP', '어요/EF', '?/SF'],
#   ['고등학교/NNP', '동창/NNP', '모임/NNP', '이/VCP', '거든/EF', './SF'],
#   ['어떤/MM', '약속/NNG', '이/VCP', '시/EP', '어요/EF', '?/SF'],
#   ['백화점/NNP', '쇼핑/NNG', '이/VCP', '야/EF', './SF'],
#   ['요일/NNP',
#    '을/JKO',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['화요일/NNP', '날/NNG', './SF'],
#   ['시간/NNG',
#    '을/JKO',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['오후/NNG', '1/SN', '시/NNB', '에/JKB', './SF'],
#   ['일정/NNG', '을/JKO', '입력/NNG', '하/XSV', '았/EP', '습니다/EF', './SF'],
#   ['내일/NNG',
#    '아침/NNG',
#    '일/NNB',
#    '7/SN',
#    '시/NNB',
#    '에/JKB',
#    '깨우/VV',
#    '어/EC',
#    '주/VX',
#    'ㄹ래/EF',
#    '?/SF'],
#   ['다시/MAG',
#    '1/SN',
#    '번/NNB',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['아름/NNP', '아/JKV', '수고/NNG', '하/XSV', '았/EP', '어/EF', './SF'],
#   ['다시/MAG',
#    '1/SN',
#    '번/NNB',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['내일/NNG',
#    '아침/NNG',
#    '7/SN',
#    '시/NNB',
#    '에/JKB',
#    '깨우/VV',
#    '어/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['알람/NNP', '을/JKO', '설정/NNG', '하/XSV', 'ㅂ니다/EF', './SF'],
#   ['아름/NNP', '아/JKV', '수고/NNG', '하/XSV', '았/EP', '어/EF', './SF'],
#   ['고마워요/NNP', './SF']],
#  [['아름/NNP', '아/JKV', '안녕/IC', '?/SF'],
#   ['안녕하세요/NNP', '?/SF'],
#   ['아름/NNP',
#    '아/JKV',
#    '일정/NNG',
#    '확인/NNG',
#    '좀/MAG',
#    '하/VV',
#    '아/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['네/IC',
#    ',/SP',
#    '언제/MAG',
#    '일정/NNG',
#    '을/JKO',
#    '확인/NNG',
#    '하/XSV',
#    'ㄹ까요/EF',
#    '?/SF'],
#   ['다음/NNG',
#    '주/NNP',
#    '일정/NNG',
#    '을/JKO',
#    '알리/VV',
#    '어/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['검색/NNG',
#    '하/XSV',
#    'ㅂ니다/EF',
#    './SF',
#    '오전/NNG',
#    '과/JC',
#    '오후/NNG',
#    '약속/NNG',
#    '이/JKS',
#    '있/VX',
#    '습니다/EF',
#    './SF'],
#   ['오전/NNP',
#    '약속/NNG',
#    '장소/NNG',
#    '를/JKO',
#    '알리/VV',
#    '어/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['약속/NNP', '장소/NNP', '는/JX', '롯데백화점/NNP', '이/VCP', 'ㅂ니다/EF', './SF'],
#   ['누구/NP',
#    '랑/JKB',
#    '약속/NNG',
#    '이/VCP',
#    'ㄴ지/EC',
#    '누구/NP',
#    '랑/JKB',
#    '약속/NNG',
#    '이/VCP',
#    '야/EF',
#    '?/SF'],
#   ['다시/MAG', '말씀/NNG', '하/XSV', '아/EC', '주/VX', '시/EP', '어요/EF', './SF'],
#   ['약속/NNG', '이/JKS', '변경/NNG', '되/XSV', '었/EP', '어/EF', './SF'],
#   ['어떤/MM', '내용/NNG', '이/JKS', '변경/NNG', '되/XSV', '었/EP', '나요/EF', '?/SF'],
#   ['약속/NNG', '날짜/NNP', '가/JKS', '바/NNB', '끼/VV', '었/EP', '어/EF', './SF'],
#   ['바뀌/VV',
#    'ㄴ/ETM',
#    '날짜/NNG',
#    '를/JKO',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['10월', '24일/NNP', '로/JKB', '변경/NNG', '되/XSV', '었/EP', '어/EF', './SF'],
#   ['시간/NNG', '도/JX', '변경/NNG', '되/XSV', '었/EP', '나요/EF', '?/SF'],
#   ['아니야/NNP',
#    ',/SP',
#    '시간/NNG',
#    '은/JX',
#    '변경/NNG',
#    '되/XSV',
#    '지/EC',
#    '않/VX',
#    '았/EP',
#    '어/EF',
#    './SF'],
#   ['네/IC',
#    ',/SP',
#    '약속/NNP',
#    '장소/NNP',
#    '는/JX',
#    '어디/NP',
#    '세/VA',
#    '요/EF',
#    '?/SF'],
#   ['장소/NNG', '는/JX', '골프장/NNG', '이/VCP', '야/EF', './SF'],
#   ['일정/NNG', '을/JKO', '변경/NNG', '하/XSV', '았/EP', '습니다/EF', './SF'],
#   ['아름/NNP', '아/JKV', '고맙/VA', '어/EF', './SF'],
#   ['또/MAJ', '부르/VV', '어/EC', '주/VX', '시/EP', '어요/EF', './SF']],
#  [['아름/NNP', '아/JKV', './SF'],
#   ['부르/VV', '시/EP', '었/EP', '어요/EF', '?/SF'],
#   ['일정/NNG',
#    '좀/MAG',
#    '일정/NNG',
#    '좀/MAG',
#    '등록/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    'ㄹ래/EF',
#    '?/SF'],
#   ['원하/VV',
#    '시/EP',
#    '는/ETM',
#    '날짜/NNG',
#    '를/JKO',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['음/NNG',
#    '다음/NNG',
#    '주',
#    '주/NNP',
#    '말로/NNP',
#    '하/VV',
#    '아/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['장소/NNG',
#    '를/JKO',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['롯데백화점/NNP', '으로/JKB', './SF'],
#   ['누구/NP', '와/JKB', '약속/NNG', '이/VCP', '시/EP', '어요/EF', '?/SF'],
#   ['고등학교/NNP', '동창/NNP', '모임/NNP', '이/VCP', '야/EF', './SF'],
#   ['어떤/MM', '약속/NNG', '이/VCP', '시/EP', '어요/EF', '?/SF'],
#   ['선물/NNG', '을/JKO', '살/VV', 'ㄹ/ETM', '것/NNB', '야/JKV', './SF'],
#   ['요일/NNP',
#    '을/JKO',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['토요일/NNG', '로/JKB', '하/VV', '아/EC', '주/VX', '어/EF', './SF'],
#   ['시간/NNG',
#    '을/JKO',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['오후/NNG', '5/SN', '시로/NNP', './SF'],
#   ['일정/NNG', '을/JKO', '입력/NNG', '하/XSV', '았/EP', '습니다/EF', './SF'],
#   ['내일/NNG',
#    '아침/NNG',
#    '7/SN',
#    '시/NNB',
#    '에/JKB',
#    '깨우/VV',
#    '어/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['네/IC', ',/SP', '알람/NNP', '을/JKO', '설정/NNG', '하/XSV', 'ㅂ니다/EF', './SF'],
#   ['아름/NNP', '아/JKV', '수고/NNG', '하/XSV', '았/EP', '어/EF', './SF'],
#   ['고마워요/NNP', './SF']],
#  [['아름/NNP', '아/JKV', './SF'],
#   ['네/IC', ',/SP', '부르/VV', '시/EP', '었/EP', '어요/EF', '?/SF'],
#   ['어/IC',
#    '일정/NNG',
#    '등록/NNP',
#    '좀/MAG',
#    '하/VV',
#    '아/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['원하/VV',
#    '시/EP',
#    '는/ETM',
#    '날짜/NNG',
#    '를/JKO',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['모레/NNG', '아침/NNG', '이/VCP', '야/EF', './SF'],
#   ['장소/NNG',
#    '를/JKO',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['이마트/NNP', './SF'],
#   ['누구/NP', '와/JKB', '약속/NNG', '이/VCP', '시/EP', '어요/EF', '?/SF'],
#   ['어/IC', '고등학교/NNP', '동창/NNP', '모임/NNP', '이/VCP', '야/EF', './SF'],
#   ['어떤/MM', '약속/NNG', '이/VCP', '시/EP', '어요/EF', '?/SF'],
#   ['백화점/NNP', '쇼핑/NNP', '할거/NNG', '야/JKV', './SF'],
#   ['다시/MAG',
#    '1/SN',
#    '번/NNB',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['백화점/NNP', '쇼핑/NNP', '할거/NNG', '야/JKV', './SF'],
#   ['약속/NNG',
#    '요일/NNP',
#    '을/JKO',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['금요일/NNP', '이/VCP', '야/EF', './SF'],
#   ['시간/NNG',
#    '을/JKO',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['오후/NNG', '4/SN', '시야/NNP', './SF'],
#   ['일정/NNG', '을/JKO', '입력/NNG', '하/XSV', '았/EP', '습니다/EF', './SF'],
#   ['내일/NNG',
#    '아침/NNG',
#    '6/SN',
#    '시/NNB',
#    '에/JKB',
#    '깨우/VV',
#    '어/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['다시/MAG',
#    '1/SN',
#    '번/NNB',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['내일/NNG',
#    '아침/NNG',
#    '9/SN',
#    '시/NNB',
#    '에/JKB',
#    '알람/NNP',
#    '설정/NNG',
#    '하/XSV',
#    '아서/EC',
#    '나/NP',
#    '좀/MAG',
#    '깨우/VV',
#    '어/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['알람/NNP', '을/JKO', '설정/NNG', '하/XSV', 'ㅂ니다/EF', './SF'],
#   ['아름/NNP', '아/JKV', '수고/NNG', '하/XSV', '았/EP', '어/EF', './SF'],
#   ['고마워요/NNP', './SF']],
#  [['아름/NNP', '아/JKV', '잘/MAG', '있/VX', '었/EP', '어/EF', '?/SF'],
#   ['네/IC', ',/SP', '잘/MAG', '있/VX', '었/EP', '어요/EF', './SF'],
#   ['아름/NNP', '아/JKV', './SF'],
#   ['왜/MAG', '부르/VV', '시/EP', '어요/EF', './SF'],
#   ['가족/NNG',
#    '모임/NNP',
#    '일정/NNG',
#    '이/JKS',
#    '있/VV',
#    '는지/EC',
#    '알/VV',
#    'ㄹ/ETM',
#    '수/NNB',
#    '있/VX',
#    '을까/EF',
#    '?/SF'],
#   ['네/IC', ',/SP', '있/VX', '습니다/EF', './SF'],
#   ['이번/NNG',
#    '달/NNG',
#    '에/JKB',
#    '가족/NNG',
#    '모임/NNG',
#    '이/JKS',
#    '언제/NP',
#    '지/EF',
#    '?/SF'],
#   ['확인/NNG',
#    '중/NNB',
#    '이/VCP',
#    'ㅂ니다/EF',
#    './SF',
#    '30/SN',
#    '일/NNB',
#    '이/VCP',
#    '에요/EF',
#    './SF'],
#   ['모임/NNG', '시간/NNG', '이/JKS', '몇/MM', '시지/NNP', '?/SF'],
#   ['네/IC',
#    ',/SP',
#    '모임/NNG',
#    '시간/NNG',
#    '은/JX',
#    '저녁/NNG',
#    '6/SN',
#    '시/NNB',
#    '에요/EF',
#    './SF'],
#   ['아/IC',
#    '다른/MM',
#    '모임/NNG',
#    '은/JX',
#    '없/VA',
#    '는/ETM',
#    '거/NNB',
#    '하/VX',
#    '겠/EP',
#    '지/EF',
#    '?/SF'],
#   ['네/IC', ',/SP', '다른/MM', '모임/NNG', '은/JX', '없/VA', '습니다/EF', './SF'],
#   ['생일/NNG',
#    '이나/JC',
#    '생일/NNG',
#    '이나/JC',
#    '기념일/NNP',
#    '은/JX',
#    '또/MAJ',
#    '없/VA',
#    '는/ETM',
#    '거/NNB',
#    '하/VX',
#    '겠/EP',
#    '지/EF',
#    '?/SF'],
#   ['아니오/IC',
#    ',/SP',
#    '28/SN',
#    '일/NNB',
#    '우철/NNP',
#    '이/JKS',
#    '오빠/NNP',
#    '생일/NNG',
#    '이/JKS',
#    '있/VX',
#    '어요/EF',
#    './SF'],
#   ['각/MM',
#    '모임/NNG',
#    '의/JKG',
#    '알람/NNP',
#    '이/JKS',
#    '설정/NNG',
#    '되/XSV',
#    '어/EC',
#    '있/VX',
#    '는지/EC',
#    '알/VV',
#    'ㄹ/ETM',
#    '수/NNB',
#    '있/VX',
#    '을까/EF',
#    '?/SF'],
#   ['네/IC',
#    ',/SP',
#    '잠시/NNG',
#    '만요/NNP',
#    './SF',
#    '알람/NNP',
#    '이/JKS',
#    '설정/NNG',
#    '되/XSV',
#    '어/EC',
#    '있/VX',
#    '지/EC',
#    '않/VX',
#    '습니다/EF',
#    './SF'],
#   ['알람/NNP',
#    '이/JKS',
#    '없/VA',
#    '는/ETM',
#    '일정/NNG',
#    '에/JKB',
#    '알람/NNP',
#    '을/JKO',
#    '설정/NNG',
#    '하/XSV',
#    '고/EC',
#    '싶/VX',
#    '은데/EF',
#    './SF'],
#   ['우철/NNP',
#    '이/JKS',
#    '오빠/NNP',
#    '생일/NNG',
#    '에/JKB',
#    '알람/NNP',
#    '을/JKO',
#    '설정/NNG',
#    '하/XSV',
#    'ㅂ니다/EF',
#    './SF'],
#   ['2/SN',
#    '시간/NNP',
#    '전/NNG',
#    '에/JKB',
#    '알람/NNP',
#    '울리/VV',
#    'ㄹ/ETM',
#    '수/NNB',
#    '있/VV',
#    '게/EC',
#    '설정/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['네/IC', ',/SP', '알/VV', '겠/EP', '어요/EF', './SF'],
#   ['고맙/VA', '어/EF', './SF', '아름/NNP', '아/JKV', './SF'],
#   ['좋/VA', '은/ETM', '1/SN', '일/NNB', '되/VV', '시/EP', '어요/EF', './SF']],
#  [['아름/NNP', '아/JKV', '안방/NNG', '으로/JKB', '오/VX', 'ㄹ래/EF', '?/SF'],
#   ['네/IC', ',/SP', '부르/VV', '시/EP', '었/EP', '어요/EF', './SF'],
#   ['이번/NNG',
#    '주/NNG',
#    '에/JKB',
#    '회사/NNG',
#    '에서/JKB',
#    '가/VV',
#    '는/ETM',
#    '연수/NNP',
#    '일정/NNG',
#    '을/JKO',
#    '알/VV',
#    'ㄹ/ETM',
#    '수/NNB',
#    '있/VX',
#    '을까/EF',
#    '?/SF'],
#   ['네/IC', ',/SP', '검색/NNG', '하/XSV', 'ㅂ니다/EF', './SF'],
#   ['연수/NNG',
#    '를/JKO',
#    '떠나/VV',
#    '는/ETM',
#    '날짜/NNP',
#    '좀/MAG',
#    '검색/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    'ㄹ래/EF',
#    '?/SF'],
#   ['날짜/NNP', '는/JX', '8월', '3일/NNP', '이/VCP', '에요/EF', './SF'],
#   ['회사/NNG',
#    '에/JKB',
#    '몇/MM',
#    '시/NNB',
#    '까지/JX',
#    '도착/NNG',
#    '하/XSV',
#    '아야/EC',
#    '하/VX',
#    '는지/EC',
#    '궁금/XR',
#    '하/XSA',
#    '거든/EC',
#    '알아보/VV',
#    '아/EC',
#    '주/VX',
#    'ㄹ래/EF',
#    '?/SF'],
#   ['네/IC',
#    ',/SP',
#    '오전/NNP',
#    '10/SN',
#    '시/NNB',
#    '까지/JX',
#    '도착/NNG',
#    '하/XSV',
#    '시/EP',
#    '어야/EC',
#    '하/VX',
#    'ㅂ니다/EF',
#    './SF'],
#   ['연수/NNP', '기간/NNG', '은/JX', '얼마나/MAG', '되/VV', '지/EF', '?/SF'],
#   ['연수/NNP', '기간/NNG', '은/JX', '3/SN', '일/NNB', '이/VCP', '에요/EF', './SF'],
#   ['연수/NNP',
#    '날짜/NNP',
#    '에/JKB',
#    '맞추/VV',
#    '어서/EC',
#    '6/SN',
#    '시로/NNP',
#    '알람/NNP',
#    '을/JKO',
#    '설정/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    'ㄹ래/EF',
#    '?/SF'],
#   ['네/IC', ',/SP', '설정/NNG', '하/XSV', 'ㅂ니다/EF', './SF'],
#   ['내일/NNG', '의/JKG', '일정/NNG', '은/JX', '뭐/NP', '지/EF', '?/SF'],
#   ['네/IC',
#    ',/SP',
#    '내일/NNG',
#    '은/JX',
#    '거래처/NNG',
#    '직원/NNG',
#    '과/JC',
#    '점심/NNP',
#    '약속/NNG',
#    '이/JKS',
#    '있/VX',
#    '으시/EP',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['내일/NNG',
#    '일정/NNG',
#    '을/JKO',
#    '다음/NNG',
#    '주/MM',
#    '일요일/NNG',
#    '로/JKB',
#    '변경/NNG',
#    '을/JKO',
#    '하/VV',
#    '고/EC',
#    '싶/VX',
#    '거든/EF',
#    './SF'],
#   ['네/IC', ',/SP', '알/VV', '겠/EP', '습니다/EF', './SF'],
#   ['다음/NNG',
#    '주/MM',
#    '일요일/NNP',
#    '오후/NNG',
#    '12/SN',
#    '시로/NNP',
#    '알람/NNP',
#    '을/JKO',
#    '설정/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    'ㄹ래/EF',
#    '?/SF'],
#   ['설정/NNG', '하/XSV', '았/EP', '습니다/EF', './SF'],
#   ['아름/NNP',
#    '아/JKV',
#    '돕/VV',
#    '아/EC',
#    '주/VX',
#    '어서/EC',
#    '고맙/VA',
#    '어/EF',
#    './SF',
#    '수고/NNG',
#    '하/XSV',
#    '았/EP',
#    '다/EF',
#    './SF'],
#   ['또/MAJ', '부르/VV', '어/EC', '주/VX', '시/EP', '어요/EF', './SF']],
#  [['아름/NNP', '아/JKV', '안녕/IC', './SF'],
#   ['안녕하세요/NNP', './SF'],
#   ['아름/NNP', '아/JKV', './SF'],
#   ['부르/VV', '시/EP', '었/EP', '어요/EF', './SF'],
#   ['오늘/NNG',
#    '어버이날/NNP',
#    '가족/NNG',
#    '모임/NNG',
#    '이/JKS',
#    '맞/VV',
#    '는지/EC',
#    '알/VV',
#    'ㄹ/ETM',
#    '수/NNB',
#    '있/VX',
#    '을까/EF',
#    '?/SF'],
#   ['네/IC',
#    ',/SP',
#    '확인/NNG',
#    '중/NNB',
#    '이/VCP',
#    'ㅂ니다/EF',
#    './SF',
#    '맞/VV',
#    '습니다/EF',
#    './SF'],
#   ['어버이날/NNP',
#    '가족/NNG',
#    '모임/NNP',
#    '일정/NNG',
#    '을/JKO',
#    '취소/NNG',
#    '하/XSV',
#    '려고/EC',
#    '하/VX',
#    '거든/EF',
#    './SF'],
#   ['네/IC', ',/SP', '취소/NNG', '하/XSV', 'ㅂ니다/EF', './SF'],
#   ['가깝/VA',
#    'ㄴ/ETM',
#    '식당/NNG',
#    '에서/JKB',
#    '식사/NNG',
#    '를/JKO',
#    '하/VV',
#    '기/ETN',
#    '로/JKB',
#    '일정/NNG',
#    '을/JKO',
#    '입력/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    'ㄹ래/EF',
#    '?/SF'],
#   ['언제/MAG', '하/XSV', '시/EP', '나요/EF', '?/SF'],
#   ['저녁/NNG', '식사/NNG', '를/JKO', '하/VV', '려고/EC', '하/VX', '아/EF', './SF'],
#   ['예/IC', ',/SP', '알/VV', '겠/EP', '습니다/EF', './SF'],
#   ['어버이날/NNP',
#    '오후/NNG',
#    '3/SN',
#    '시로/NNP',
#    '알람/NNP',
#    '을/JKO',
#    '설정/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    'ㄹ래/EF',
#    '?/SF'],
#   ['알람/NNP', '을/JKO', '설정/NNG', '하/XSV', 'ㅂ니다/EF', './SF'],
#   ['설정/NNG',
#    '이/JKS',
#    '잘/MAG',
#    '되/VV',
#    '었/EP',
#    '는지/EC',
#    '다시/MAG',
#    '1/SN',
#    '번/NNB',
#    '확인/NNG',
#    '하/XSV',
#    '아/EC',
#    '보/VX',
#    '아/EF',
#    './SF'],
#   ['네/IC', ',/SP', '설정/NNG', '이/JKS', '되/VV', '었/EP', '어요/EF', './SF'],
#   ['선물/NNG',
#    '을/JKO',
#    '사/VV',
#    '아야/EC',
#    '하/VX',
#    '니까/EC',
#    '백화점/NNP',
#    '의/JKG',
#    '영업/NNG',
#    '일/NNG',
#    '을/JKO',
#    '좀/MAG',
#    '알아보/VV',
#    '아/EC',
#    '주/VX',
#    'ㄹ래/EF',
#    '?/SF'],
#   ['네/IC',
#    ',/SP',
#    '백화점/NNG',
#    '은/JX',
#    '2/SN',
#    '째/XSN',
#    ',/SP',
#    '4/SN',
#    '째/XSN',
#    '월요일/NNP',
#    '만/JX',
#    '쉬/VV',
#    'ㅂ니다/EF',
#    './SF'],
#   ['어버이/NNG',
#    '전날/NNG',
#    '에/JKB',
#    '백화점/NNG',
#    '을/JKO',
#    '가/VV',
#    '려고/EC',
#    '하/VX',
#    '거든/EF',
#    './SF',
#    '일정/NNG',
#    '을/JKO',
#    '입력/NNG',
#    '하/XSV',
#    '아/EC',
#    '놓/VV',
#    '아/EF',
#    './SF'],
#   ['네/IC',
#    ',/SP',
#    '일정/NNG',
#    '을/JKO',
#    '입력/NNG',
#    '하/XSV',
#    '았/EP',
#    '어요/EF',
#    './SF'],
#   ['아름/NNP',
#    '아/JKV',
#    '돕/VV',
#    '아/EC',
#    '주/VX',
#    '어서/EC',
#    '고맙/VA',
#    '다/EF',
#    './SF',
#    '수고/NNG',
#    '하/XSV',
#    '았/EP',
#    '어/EF',
#    './SF'],
#   ['네/IC', ',/SP', '수고/NNG', '하/XSV', '시/EP', '었/EP', '습니다/EF', './SF']],
#  [['아름/NNP', '아/JKV', '방/NNG', '으로/JKB', '오/VX', 'ㄹ래/EF', '?/SF'],
#   ['네/IC', ',/SP', '저/MM', '오/VX', '았/EP', '어요/EF', './SF'],
#   ['아름/NNP', '아/JKV', '안녕/IC', '?/SF'],
#   ['안녕하세요/NNP', '?/SF'],
#   ['다음/NNG',
#    '달/NNG',
#    '친구/NNG',
#    '생일/NNG',
#    '이/JKS',
#    '언제/NP',
#    '이/VCP',
#    'ㄴ지/EC',
#    '찾/VV',
#    '아/EC',
#    '주/VX',
#    'ㄹ래/EF',
#    '?/SF'],
#   ['네/IC',
#    ',/SP',
#    '잠시/NNG',
#    '만요/NNP',
#    './SF',
#    '8/SN',
#    '일/NNB',
#    '이/VCP',
#    'ㅂ니다/EF',
#    './SF'],
#   ['친구/NNG',
#    '생일/NNP',
#    '전날/NNG',
#    '로/JKB',
#    '알람/NNP',
#    '을/JKO',
#    '설정/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    'ㄹ래/EF',
#    '?/SF'],
#   ['네/IC', ',/SP', '몇/MM', '시로/NNP', '설정/NNG', '하/XSV', 'ㄹ까요/EF', '?/SF'],
#   ['어/IC',
#    '알람/NNP',
#    '시각/NNP',
#    '은/JX',
#    '오후/NNG',
#    '9/SN',
#    '시로/NNP',
#    '하/VV',
#    '아/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['네/IC',
#    ',/SP',
#    '알/VV',
#    '겠/EP',
#    '습니다/EF',
#    './SF',
#    '다른/MM',
#    '알람/NNP',
#    '과/JC',
#    '중복/NNG',
#    '되/XSV',
#    '었/EP',
#    '어요/EF',
#    './SF'],
#   ['어/IC',
#    '오후/NNG',
#    '9/SN',
#    '시/NNB',
#    '에/JKB',
#    '어떤/MM',
#    '알람/NNP',
#    '과/JC',
#    '겹치/VV',
#    '지/EF',
#    '?/SF'],
#   ['네/IC',
#    ',/SP',
#    '할머니/NNG',
#    '께/JKB',
#    '전화/NNG',
#    '하/XSV',
#    '기/ETN',
#    '로/JKB',
#    '한/MM',
#    '알람/NNP',
#    '이/VCP',
#    '에요/EF',
#    './SF'],
#   ['친구/NNG',
#    '생일/NNP',
#    '알람/NNP',
#    '을/JKO',
#    '밤/NNG',
#    '12/SN',
#    '시로/NNP',
#    '바꾸/VV',
#    '어/EC',
#    '주/VX',
#    'ㄹ래/EF',
#    '?/SF'],
#   ['알/VV', '겠/EP', '습니다/EF', './SF'],
#   ['알람/NNP', '을/JKO', '확인/NNG', '하/XSV', '아/EF', './SF'],
#   ['다시/MAG', '말씀/NNG', '하/XSV', '시/EP', '어요/EF', './SF'],
#   ['알람/NNP', '을/JKO', '확인/NNG', '하/XSV', '아/EF', './SF'],
#   ['네/IC',
#    ',/SP',
#    '밤/NNG',
#    '12/SN',
#    '시로/NNP',
#    '알람/NNP',
#    '이/JKS',
#    '설정/NNG',
#    '되/XSV',
#    '었/EP',
#    '습니다/EF',
#    './SF'],
#   ['오늘/NNG',
#    '의/JKG',
#    '일정/NNG',
#    '을/JKO',
#    '확인/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    'ㄹ래/EF',
#    '?/SF'],
#   ['잠시/NNG',
#    '만요/NNP',
#    './SF',
#    '5/SN',
#    '시/NNB',
#    '에/JKB',
#    '미술/NNP',
#    '학원/NNP',
#    '에/JKB',
#    '가시/VV',
#    '어야/EC',
#    '하/VX',
#    '아요/EF',
#    './SF'],
#   ['아름/NNP', '아/JKV', '고맙/VA', '어/EF', './SF'],
#   ['아니/VCN', '에요/EF', './SF']],
#  [['아름/NNP', '아/JKV', '안녕/IC', '?/SF'],
#   ['안녕하세요/NNP', '?/SF'],
#   ['스케줄/NNP',
#    '땜/NNB',
#    '에/JKB',
#    '물어보/VV',
#    'ㄹ/ETM',
#    '게/NNG',
#    '있/VV',
#    '어서/EC',
#    '부르/VV',
#    '었/EP',
#    '어/EF',
#    './SF'],
#   ['네/IC',
#    ',/SP',
#    '무엇/NP',
#    '을/JKO',
#    '알리/VV',
#    '어/EC',
#    '드리/VX',
#    'ㄹ까요/EF',
#    '?/SF'],
#   ['이번/NNG',
#    '주말/NNP',
#    '스케줄/NNP',
#    '을/JKO',
#    '확인/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    'ㄹ래/EF',
#    '?/SF'],
#   ['토요일/NNP',
#    '과/JC',
#    '일요일/NNP',
#    '중/NNB',
#    '선택/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['토요일/NNP', './SF'],
#   ['네/IC',
#    ',/SP',
#    '검색/NNG',
#    '하/XSV',
#    'ㅂ니다/EF',
#    './SF',
#    '골프/NNP',
#    '약속/NNP',
#    '이/JKS',
#    '있/VX',
#    '으시/EP',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['골프/NNP',
#    '약속/NNP',
#    '의/JKG',
#    '일정/NNG',
#    '을/JKO',
#    '좀/MAG',
#    '취소/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    'ㄹ래/EF',
#    '?/SF'],
#   ['네/IC', ',/SP', '취소/NNG', '하/XSV', 'ㅂ니다/EF', './SF'],
#   ['대학교/NNG',
#    '동기/NNP',
#    '모임/NNP',
#    '의/JKG',
#    '일정/NNG',
#    '을/JKO',
#    '좀/MAG',
#    '입력/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    'ㄹ래/EF',
#    '?/SF'],
#   ['네/IC',
#    ',/SP',
#    '말씀/NNG',
#    '하/XSV',
#    '시/EP',
#    '어요/EF',
#    './SF',
#    '며칠/NNG',
#    '이/VCP',
#    '에요/EF',
#    '?/SF'],
#   ['어/IC', '16/SN', '일/NNB', './SF'],
#   ['네/IC', ',/SP', '입력/NNG', '하/XSV', 'ㅂ니다/EF', './SF'],
#   ['입력/NNP',
#    '이/JKS',
#    '잘/MAG',
#    '되/VV',
#    '었/EP',
#    '는지/EC',
#    '다시/MAG',
#    '확인/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    'ㄹ래/EF',
#    '?/SF'],
#   ['입력/NNP', '이/JKS', '잘/MAG', '되/VV', '었/EP', '어요/EF', './SF'],
#   ['오늘/NNG',
#    '의/JKG',
#    '일정/NNG',
#    '을/JKO',
#    '확인/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    'ㄹ래/EF',
#    '?/SF'],
#   ['네/IC',
#    ',/SP',
#    '저녁/NNG',
#    '에/JKB',
# ...
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['7월', '18일/NNP', '로/JKB', '변경/NNG', '되/XSV', '었/EP', '어/EF', './SF'],
#   ['시간/NNG', '도/JX', '변경/NNG', '되/XSV', '었/EP', '나요/EF', '?/SF'],
#   ['아니/IC',
#    ',/SP',
#    '시간/NNG',
#    '은/JX',
#    '같/VA',
#    '은/ETM',
#    '시간/NNG',
#    '이/VCP',
#    '야/EF',
#    './SF'],
#   ['알/VV',
#    '겠/EP',
#    '습니다/EF',
#    './SF',
#    '장소/NNG',
#    '는/JX',
#    '어디/NP',
#    '세/VA',
#    '요/EF',
#    '?/SF'],
#   ['장소/NNG',
#    '는/JX',
#    '친구/NNG',
#    '미영/NNP',
#    '이/VCP',
#    '네/EC',
#    '집/NNG',
#    '이/VCP',
#    '야/EF',
#    './SF'],
#   ['네/IC',
#    ',/SP',
#    '일정/NNG',
#    '을/JKO',
#    '변경/NNG',
#    '하/XSV',
#    '았/EP',
#    '습니다/EF',
#    './SF'],
#   ['아름/NNP', '아/JKV', '고맙/VA', '어/EF', './SF'],
#   ['또/MAJ', '부르/VV', '어/EC', '주/VX', '시/EP', '어요/EF', './SF']],
#  [['아름/NNP', '아/JKV', './SF'],
#   ['부르/VV', '시/EP', '었/EP', '어요/EF', '?/SF'],
#   ['아름/NNP',
#    '아/JKV',
#    '일정/NNG',
#    '등록/NNP',
#    '좀/MAG',
#    '하/VV',
#    '아/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['원하/VV',
#    '시/EP',
#    '는/ETM',
#    '날짜/NNG',
#    '를/JKO',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['주말/NNP', '로/JKB', '하/VV', '아/EC', '주/VX', '어/EF', './SF'],
#   ['장소/NNG',
#    '를/JKO',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['종로/NNP', '영화관/NNP', './SF'],
#   ['누구/NP', '와/JKB', '약속/NNG', '이/VCP', '시/EP', '어요/EF', '?/SF'],
#   ['가족/NNG', '모임/NNG', '이/VCP', '야/EF', './SF'],
#   ['어떤/MM', '약속/NNG', '이/VCP', '시/EP', '어요/EF', '?/SF'],
#   ['콘서트/NNP', '보/VV', '기/ETN', '로/JKB', '하/VV', '았/EP', '어/EF', './SF'],
#   ['요일/NNP',
#    '을/JKO',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['수요일/NNP', '이/VCP', '야/EF', './SF'],
#   ['시간/NNG',
#    '을/JKO',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['오후/NNG', '2시/NNP', '야/JKV', './SF'],
#   ['네/IC',
#    ',/SP',
#    '일정/NNG',
#    '을/JKO',
#    '입력/NNG',
#    '하/XSV',
#    '았/EP',
#    '습니다/EF',
#    './SF'],
#   ['내일/NNG',
#    '아침/NNG',
#    '9/SN',
#    '시/NNB',
#    '에/JKB',
#    '깨우/VV',
#    '어/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['알람/NNP', '을/JKO', '설정/NNG', '하/XSV', 'ㅂ니다/EF', './SF'],
#   ['아름/NNP', '아/JKV', '정말/MAG', '수고/NNG', '하/XSV', '았/EP', '어/EF', './SF'],
#   ['고마워요/NNP', './SF']],
#  [['아름/NNP', '아/JKV', './SF'],
#   ['부르/VV', '시/EP', '었/EP', '어요/EF', '?/SF'],
#   ['어/IC',
#    '시험/NNG',
#    '공부/NNG',
#    '하/XSV',
#    '는데/EC',
#    '지금/MAG',
#    '너무/MAG',
#    '졸/NNG',
#    '립/NNG',
#    '다/JX',
#    './SF'],
#   ['제가/NNP', '어떻/VA', '게/EC', '돕/VV', '아/EC', '드리/VX', 'ㄹ까요/EF', '?/SF'],
#   ['어/IC', '나/NP', '잠깐/MAG', '자/VV', '고/EC', '일어나/VV', 'ㄹ게/EF', './SF'],
#   ['알/VV', '겠/EP', '어요/EF', './SF'],
#   ['알람/NNP', '좀/MAG', '설정/NNG', '하/XSV', '아/EC', '주/VX', '어/EF', './SF'],
#   ['어떻/VA', '게/EC', '설정/NNG', '하/XSV', 'ㄹ까요/EF', '?/SF'],
#   ['어/IC',
#    '지금/NNG',
#    '부터/JX',
#    '1/SN',
#    '시간/NNP',
#    '뒤/NNG',
#    '로/JKB',
#    '좀/MAG',
#    '하/VV',
#    '아/EC',
#    '주/VX',
#    'ㄹ래/EF',
#    '?/SF'],
#   ['알람/NNP', '을/JKO', '설정/NNG', '하/XSV', 'ㅂ니다/EF', './SF'],
#   ['내일/NNG',
#    '시험/NNG',
#    '과목/NNG',
#    '이/JKS',
#    '뭐/NP',
#    '이/VCP',
#    '었/EP',
#    '지/EF',
#    '?/SF'],
#   ['네/IC',
#    './SF',
#    '세계사/NNG',
#    ',/SP',
#    '한문/NNP',
#    ',/SP',
#    '영어/NNP',
#    '에요/EF',
#    './SF'],
#   ['시험/NNG', '시간/NNG', '좀/MAG', '가르치/VV', '어/EC', '주/VX', 'ㄹ래/EF', '?/SF'],
#   ['9/SN', '시/NNB', '-/SS', '12/SN', '시/NNB', '까지/VV', '에요/EF', './SF'],
#   ['어/IC',
#    '공부/NNG',
#    '하/XSV',
#    'ㄹ/ETM',
#    '게/NNG',
#    '너무/MAG',
#    '많/VA',
#    '다/EF',
#    './SF',
#    '알람/NNP',
#    '좀/MAG',
#    '알람/NNP',
#    '시간/NNG',
#    '좀/MAG',
#    '바꾸/VV',
#    '자/EF',
#    './SF'],
#   ['어떻/VA', '게/EC', '변경/NNG', '하/XSV', 'ㄹ까요/EF', '?/SF'],
#   ['어/IC',
#    '알람/NNP',
#    '다시/MAG',
#    '30/SN',
#    '분/NNB',
#    '뒤/NNG',
#    '로/JKB',
#    '하/VV',
#    '아/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['30/SN', '분/NNB', '뒤/NNG', '로/JKB', '변경/NNG', '하/XSV', 'ㅂ니다/EF', './SF'],
#   ['어/IC', '아름/NNP', '아/JKV', '진짜/MAG', '고맙/VA', '어/EF', './SF'],
#   ['아니/VCN', '에요/EF', './SF']],
#  [['아름/NNP',
#    '아/JKV',
#    '안방/NNG',
#    '으로/JKB',
#    '오/VV',
#    '아/EC',
#    '보/VX',
#    '아/EF',
#    './SF'],
#   ['네/IC', ',/SP', '엄마/NNG', '저/MM', '여기/NP', '오/VX', '았/EP', '어요/EF', './SF'],
#   ['아름/NNP', '아/JKV', '안녕/IC', '?/SF'],
#   ['엄마/NNG', '도/JX', '안녕하세요/NNP', './SF'],
#   ['아름/NNP',
#    '아/JKV',
#    '연수/NNP',
#    '떠나/VV',
#    '는/ETM',
#    '날짜/NNP',
#    '좀/MAG',
#    '검색/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['네/IC',
#    ',/SP',
#    '검색/NNG',
#    '하/XSV',
#    'ㅂ니다/EF',
#    './SF',
#    '7월',
#    '5일/NNP',
#    '이/VCP',
#    'ㅂ니다/EF',
#    './SF'],
#   ['몇/MM',
#    '시/NNB',
#    '까지/JX',
#    '도착/NNG',
#    '하/XSV',
#    '아야/EC',
#    '하/VV',
#    '는지/EC',
#    '검색/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['오전/NNP', '10/SN', '시/NNB', '까지/VV', '에요/EF', './SF'],
#   ['연수/NNP',
#    '기간/NNG',
#    '을/JKO',
#    '검색/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['검색/NNP',
#    '중/NNB',
#    '이/VCP',
#    'ㅂ니다/EF',
#    './SF',
#    '기간/NNG',
#    '은/JX',
#    '3/SN',
#    '일/NNB',
#    '이/VCP',
#    '에요/EF',
#    './SF'],
#   ['연수/NNP',
#    '날짜/NNP',
#    '에/JKB',
#    '맞추/VV',
#    '어/EC',
#    '7/SN',
#    '시로/NNP',
#    '알람/NNP',
#    '설정/NNG',
#    '좀/MAG',
#    '하/VV',
#    '아/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['네/IC', ',/SP', '설정/NNG', '되/XSV', '었/EP', '습니다/EF', './SF'],
#   ['내일/NNG',
#    '의/JKG',
#    '일정/NNG',
#    '좀/MAG',
#    '검색/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['검색/NNP',
#    '중/NNB',
#    '이/VCP',
#    'ㅂ니다/EF',
#    './SF',
#    '내일/NNG',
#    '은/JX',
#    '거래처/NNG',
#    '직원/NNG',
#    '과/JC',
#    '점심/NNP',
#    '약속/NNP',
#    '이/JKS',
#    '있/VX',
#    '으시/EP',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['내일/NNG',
#    '일정/NNG',
#    '을/JKO',
#    '다음/NNG',
#    '주/NNP',
#    '토요일/NNG',
#    '로/JKB',
#    '변경/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['네/IC', ',/SP', '변경/NNG', '하/XSV', 'ㅂ니다/EF', './SF'],
#   ['다음/NNG',
#    '주/NNP',
#    '토요일',
#    '오후/NNP',
#    '1/SN',
#    '시로/NNP',
#    '알람/NNP',
#    '설정/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['오후/NNG', '1/SN', '시/NNB', '말씀/NNG', '이/VCP', '시/EP', '어요/EF', '?/SF'],
#   ['다음/NNG',
#    '주/NNP',
#    '토요일',
#    '오후/NNP',
#    '1/SN',
#    '시로/NNP',
#    '알람/NNP',
#    '설정/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['네/IC', ',/SP', '설정/NNG', '되/XSV', '었/EP', '습니다/EF', './SF'],
#   ['아름/NNP', '아/JKV', '수고/NNG', '하/XSV', '았/EP', '어/EF', './SF'],
#   ['아니/VCN', '에요/EF', './SF']],
#  [['아름/NNP', '아/JKV', '잘/MAG', '있/VX', '었/EP', '어/EF', '?/SF'],
#   ['네/IC', ',/SP', '잘/MAG', '있/VX', '었/EP', '어요/EF', './SF'],
#   ['아름/NNP',
#    '아/JKV',
#    '안방/NNG',
#    '으로/JKB',
#    '오/VV',
#    '아/EC',
#    '보/VX',
#    '아/EF',
#    './SF'],
#   ['네/IC', ',/SP', '알/VV', '겠/EP', '습니다/EF', './SF'],
#   ['아름/NNP',
#    '아/JKV',
#    '백화점/NNG',
#    '에/JKB',
#    '가/VV',
#    '기/ETN',
#    '로/JKB',
#    '한/MM',
#    '날/NNG',
#    '이/JKS',
#    '언제/NP',
#    '이/VCP',
#    '었/EP',
#    '지/EF',
#    '?/SF'],
#   ['네/IC', ',/SP', '이번/NNG', '주/MM', '토요일/NNG', '이/VCP', 'ㅂ니다/EF', './SF'],
#   ['친구/NNG',
#    '와/JC',
#    '몇/MM',
#    '시/NNB',
#    '에/JKB',
#    '약속/NNG',
#    '이/JKS',
#    '있/VX',
#    '어/EF',
#    '?/SF'],
#   ['확인/NNG',
#    '중/NNB',
#    '이/VCP',
#    'ㅂ니다/EF',
#    './SF',
#    '오후/NNG',
#    '3/SN',
#    '시/NNB',
#    '이/VCP',
#    'ㅂ니다/EF',
#    './SF'],
#   ['만나/VV', '는/ETM', '장소/NNG', '는/JX', '어디/NP', '야/JKV', '?/SF'],
#   ['네/IC', ',/SP', '명동/NNP', '의/JKG', '롯데백화점/NNP', '이/VCP', 'ㅂ니다/EF', './SF'],
#   ['오늘/NNG',
#    '일정/NNG',
#    '이/JKS',
#    '비/VV',
#    '어/EC',
#    '있/VX',
#    '는/ETM',
#    '시간/NNG',
#    '을/JKO',
#    '찾아보/VV',
#    '아/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['잠시/NNG',
#    '만요/NNP',
#    './SF',
#    '오후/NNG',
#    '5/SN',
#    '시/NNB',
#    '-/SS',
#    '7/SN',
#    '시/NNB',
#    '까지/JX',
#    '이/VCP',
#    'ㅂ니다/EF',
#    './SF'],
#   ['그/MM',
#    '시간/NNG',
#    '에/JKB',
#    '빨래/NNG',
#    '를/JKO',
#    '하/VV',
#    '아야/EC',
#    '하/VX',
#    '겠/EP',
#    '어/EF',
#    './SF'],
#   ['네/IC', ',/SP', '알람/NNP', '을/JKO', '설정/NNG', '하/XSV', 'ㄹ까요/EF', '?/SF'],
#   ['어/IC',
#    '알람/NNP',
#    '은/JX',
#    '안/NNG',
#    '하/XSV',
#    '아도/EC',
#    '되/VV',
#    '어/EF',
#    './SF'],
#   ['알/VV', '겠/EP', '습니다/EF', './SF'],
#   ['가족/NNG',
#    '이/JKS',
#    '모두/MAG',
#    '외출/NNG',
#    '하/XSV',
#    '는/ETM',
#    '시간/NNG',
#    '이/JKS',
#    '언제/NP',
#    '야/JKV',
#    '?/SF'],
#   ['네/IC', ',/SP', '오전/NNP', '10/SN', '시/NNB', '이/VCP', 'ㅂ니다/EF', './SF'],
#   ['지영/NNP',
#    '이/NNP',
#    '가/JKS',
#    '학원/NNP',
#    '가/VV',
#    '는/ETM',
#    '시간/NNG',
#    '이/JKS',
#    '몇/MM',
#    '시지/NNP',
#    '?/SF'],
#   ['잠시/NNG', '만요/NNP', './SF', '오후/NNG', '3/SN', '시/NNB', '에요/EF', './SF'],
#   ['지영/NNP',
#    '이/NNP',
#    '가/JKS',
#    '나가/VV',
#    '기/ETN',
#    '1/SN',
#    '시간/NNP',
#    '전/NNG',
#    '에/JKB',
#    '알람/NNP',
#    '을/JKO',
#    '맞추/VV',
#    '어/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['네/IC', ',/SP', '알/VV', '겠/EP', '습니다/EF', './SF'],
#   ['아름/NNP', '아/JKV', '고맙/VA', '어/EF', './SF'],
#   ['아니/VCN', '에요/EF', './SF']],
#  [['아름/NNP', '아/JKV', '안방/NNG', '으로/JKB', '오/VX', '아/EF', './SF'],
#   ['네/IC', ',/SP', '엄마/NNG', '저/MM', '오/VX', '았/EP', '어요/EF', './SF'],
#   ['아름/NNP', '이/JKS', '잘/MAG', '있/VX', '었/EP', '어/EF', '?/SF'],
#   ['네/IC',
#    ',/SP',
#    '엄마/NNG',
#    '도/JX',
#    '안녕/NNG',
#    '하/XSV',
#    '시/EP',
#    '었/EP',
#    '어요/EF',
#    '?/SF'],
#   ['할머니/NNG', '제사/NNG', '가/JKS', '언제/NP', '야/JKV', '?/SF'],
#   ['네/IC',
#    ',/SP',
#    '할머니/NNG',
#    '제사/NNG',
#    '는/JX',
#    '이번/NNG',
#    '주/MM',
#    '토요일/NNG',
#    '이/VCP',
#    'ㅂ니다/EF',
#    './SF'],
#   ['그날/NNG',
#    '스케줄/NNP',
#    '을/JKO',
#    '좀/MAG',
#    '확인/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    'ㄹ래/EF',
#    '?/SF'],
#   ['다시/MAG',
#    '1/SN',
#    '번/NNB',
#    '말씀/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['그날/NNG',
#    '스케줄/NNP',
#    '좀/MAG',
#    '확인/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['누구/NP', '의/JKG', '스케줄/NNP', '을/JKO', '확인/NNG', '하/XSV', 'ㄹ까요/EF', '?/SF'],
#   ['엄마/NNG',
#    '스케줄/NNP',
#    '좀/MAG',
#    '확인/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['네/IC',
#    ',/SP',
#    '알/VV',
#    '겠/EP',
#    '습니다/EF',
#    './SF',
#    '그날/NNG',
#    '엄마/NNG',
#    '는/JX',
#    '동창/NNP',
#    '모임/NNP',
#    '이/JKS',
#    '있/VX',
#    '어요/EF',
#    './SF'],
#   ['동창/NNP',
#    '모임/NNP',
#    '스케줄/NNP',
#    '을/JKO',
#    '2/SN',
#    '주/NNB',
#    '뒤/NNG',
#    '로/JKB',
#    '연기/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['네/IC', ',/SP', '연기/NNG', '하/XSV', 'ㅂ니다/EF', './SF'],
#   ['내일/NNG',
#    '오전/NNP',
#    '11/SN',
#    '시/NNB',
#    '에/JKB',
#    '전화/NNG',
#    '하/XSV',
#    'ㄹ/ETM',
#    '걸/VV',
#    '니까/EC',
#    '10/SN',
#    '시/NNB',
#    '에/JKB',
#    '알람/NNP',
#    '을/JKO',
#    '맞추/VV',
#    '어/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['네/IC',
#    ',/SP',
#    '오전/NNP',
#    '10/SN',
#    '시로/NNP',
#    '알람/NNP',
#    '을/JKO',
#    '설정/NNG',
#    '하/XSV',
#    'ㅂ니다/EF',
#    './SF'],
#   ['일정/NNG',
#    '에/JKB',
#    '할머니/NNG',
#    '제사/NNG',
#    '를/JKO',
#    '새로/MAG',
#    '등록/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['네/IC', ',/SP', '등록/NNG', '하/XSV', '았/EP', '습니다/EF', './SF'],
#   ['그/MM',
#    '전날/NNG',
#    '시장/NNG',
#    '가/VV',
#    '는/ETM',
#    '일정/NNG',
#    '도/JX',
#    '등록/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['등록/NNG', '되/XSV', '었/EP', '습니다/EF', './SF'],
#   ['아빠/NNG',
#    '의/JKG',
#    '일정/NNG',
#    '에/JKB',
#    '도/JX',
#    '등록/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['네/IC', ',/SP', '알/VV', '겠/EP', '습니다/EF', './SF'],
#   ['아름/NNP', '아/JKV', '안녕/IC', './SF'],
#   ['네/IC', './SF']],
#  [['아름/NNP', '아/JKV', '안녕/IC', '?/SF'],
#   ['안녕하세요/NNP', './SF'],
#   ['아름/NNP', '아/JKV', '이리로/MAG', '오/VV', '아/EC', '보/VX', '아/EF', './SF'],
#   ['부르/VV', '시/EP', '었/EP', '어요/EF', '?/SF'],
#   ['9월/NNP',
#    '달/NNG',
#    '에/JKB',
#    '내/NNB',
#    '친구/NNP',
#    '생일/NNG',
#    '이/JKS',
#    '있/VV',
#    '는/ETM',
#    '있/VV',
#    '는지/EC',
#    '확인/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    'ㄹ래/EF',
#    '?/SF'],
#   ['다시/MAG', '말씀/NNG', '하/XSV', '아/EC', '주/VX', '시/EP', '어요/EF', './SF'],
#   ['9월/NNP',
#    '달/NNG',
#    '에/JKB',
#    '내/NNB',
#    '친구/NNP',
#    '생일/NNG',
#    '이/JKS',
#    '있/VV',
#    '는지/EC',
#    '알아보/VV',
#    '아/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['네/IC',
#    ',/SP',
#    '잠시/NNG',
#    '만요/NNP',
#    './SF',
#    '생일/NNG',
#    '이/JKS',
#    '있/VX',
#    '습니다/EF',
#    './SF'],
#   ['정확/XR',
#    '하/XSA',
#    'ㄴ/ETM',
#    '날짜/NNP',
#    '가/JKS',
#    '어떻/VA',
#    '게/EC',
#    '되/VV',
#    '는데/EF',
#    '?/SF'],
#   ['네/IC',
#    ',/SP',
#    '친구/NNG',
#    '의/JKG',
#    '날짜/NNP',
#    '는/JX',
#    '9월',
#    '5일/NNP',
#    '이/VCP',
#    '에요/EF',
#    './SF'],
#   ['친구/NNG',
#    '한테/JKB',
#    '축하/NNG',
#    '메시지/NNG',
#    '를/JKO',
#    '보내/VV',
#    'ㄹ/ETM',
#    '알람/NNP',
#    '을/JKO',
#    '설정/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    'ㄹ래/EF',
#    '?/SF'],
#   ['네/IC', ',/SP', '몇/MM', '시로/NNP', '설정/NNG', '하/XSV', 'ㄹ까요/EF', '?/SF'],
#   ['알람/NNP',
#    '시간/NNG',
#    '은/JX',
#    '생일날/NNG',
#    '아침/NNG',
#    '8/SN',
#    '시로/NNP',
#    '하/VV',
#    '아/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['네/IC', ',/SP', '설정/NNG', '하/XSV', '았/EP', '습니다/EF', './SF'],
#   ['등산/NNP',
#    '모임/NNG',
#    '이/JKS',
#    '있/VV',
#    '는/ETM',
#    '날/NNG',
#    '은/JX',
#    '언제/NP',
#    '지/EF',
#    '?/SF'],
#   ['잠시/NNG', '만요/NNP', './SF', '7월', '25일/NNP', '이/VCP', '에요/EF', './SF'],
#   ['장소/NNG', '는/JX', '어디/NP', '야/JKV', '?/SF'],
#   ['북한산/NNP', '이/VCP', '에요/EF', './SF'],
#   ['시간/NNG', '은/JX', '어떻/VA', '게/EC', '되/VV', '지/EF', '?/SF'],
#   ['네/IC', ',/SP', '오전/NNP', '10/SN', '시/NNB', '이/VCP', 'ㅂ니다/EF', './SF'],
#   ['그날/NNG',
#    '엄마/NNG',
#    '의/JKG',
#    '일정/NNG',
#    '을/JKO',
#    '비우/VV',
#    '어/EC',
#    '주/VX',
#    'ㄹ래/EF',
#    '?/SF'],
#   ['네/IC', ',/SP', '알/VV', '겠/EP', '습니다/EF', './SF'],
#   ['아름/NNP', '아/JKV', '잘/MAG', '하/XSV', '았/EP', '어/EF', './SF'],
#   ['아니/VCN', '에요/EF', './SF']],
#  [['아름/NNP', '아/JKV', '반갑/VA', '어/EF', './SF'],
#   ['반갑습니다/NNP', './SF'],
#   ['아름/NNP', '아/JKV', '이리/MAG', '좀/MAG', '오/VX', '아/EF', './SF'],
#   ['어디/NP', '로/JKB', '가/VV', 'ㄹ까요/EF', '?/SF'],
#   ['아름/NNP', '아/JKV', '거실/NNP', '로/JKB', '좀/MAG', '오/VX', 'ㄹ래/EF', '?/SF'],
#   ['네/IC', ',/SP', '부르/VV', '시/EP', '었/EP', '어요/EF', './SF'],
#   ['다음/NNG',
#    '달/NNG',
#    '에/JKB',
#    '가족/NNG',
#    '행사/NNG',
#    '할거/NNG',
#    '거/NNB',
#    '이/VCP',
#    '든/EF',
#    './SF'],
#   ['네/IC', ',/SP', '어떻/VA', '게/EC', '하/VX', 'ㄹ까요/EF', '?/SF'],
#   ['우철/NNP',
#    '이/JKS',
#    '다음/NNG',
#    '달/NNG',
#    '일요일/NNP',
#    '일정/NNG',
#    '좀/MAG',
#    '알리/VV',
#    '어/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['네/IC',
#    ',/SP',
#    '우철/NNP',
#    '오빠/NNP',
#    '는/JX',
#    '1/SN',
#    '째/XSN',
#    '주/NNB',
#    '친구/NNG',
#    '생일/NNP',
#    '파티/NNP',
#    '가/JKS',
#    '있/VX',
#    '습니다/EF',
#    './SF'],
#   ['지영/NNP',
#    '이/JKS',
#    '다음/NNG',
#    '달/NNG',
#    '일요일/NNP',
#    '일정/NNG',
#    '도/JX',
#    '알리/VV',
#    '어/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['네/IC',
#    ',/SP',
#    '지영/NNP',
#    '언니/NNG',
#    '는/JX',
#    '2/SN',
#    '째/XSN',
#    '주/NNB',
#    '학교/NNG',
#    '행사/NNP',
#    ',/SP',
#    '4/SN',
#    '째/XSN',
#    '주/NNB',
#    '친구/NNG',
#    '와/JC',
#    '영화/NNG',
#    '보기/NNP',
#    '약속/NNG',
#    '이/JKS',
#    '있/VX',
#    '어요/EF',
#    './SF'],
#   ['2/SN',
#    '다/MAG',
#    '비/VV',
#    '는/ETM',
#    '날/NNG',
#    '이/JKS',
#    '언제/NP',
#    'ㄴ지/EC',
#    '알리/VV',
#    '어/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['3/SN', '째/XSN', '주/NNB', '일요일/NNG', '이/VCP', '에요/EF', './SF'],
#   ['그럼/MAJ',
#    '3/SN',
#    '째/XSN',
#    '주/NNB',
#    '일요일/NNP',
#    '행사/NNG',
#    '를/JKO',
#    '하/VV',
#    '아야/EC',
#    '하/VX',
#    '겠/EP',
#    '거든/EF',
#    './SF'],
#   ['네/IC',
#    ',/SP',
#    '그날/NNG',
#    '은/JX',
#    '약속/NNG',
#    '이/JKS',
#    '있/VX',
#    '으시/EP',
#    '시/EP',
#    '어요/EF',
#    './SF'],
#   ['내/NP',
#    '가/JKS',
#    '약속/NNG',
#    '을/JKO',
#    '미루/VV',
#    'ㄹ/ETM',
#    '수/NNB',
#    '있/VX',
#    '어/EF',
#    './SF'],
#   ['그렇/VA', '군요/EF', './SF', '알/VV', '겠/EP', '습니다/EF', './SF'],
#   ['다음/NNG',
#    '달/NNG',
#    '3/SN',
#    '째/XSN',
#    '주/NNB',
#    '일요일/NNG',
#    '에/JKB',
#    '가족/NNG',
#    '행사/NNG',
#    '를/JKO',
#    '하/VX',
#    'ㄹ게/EF',
#    './SF'],
#   ['네/IC', ',/SP', '알/VV', '겠/EP', '어요/EF', './SF'],
#   ['엄마/NNG',
#    '일정/NNG',
#    '좀/MAG',
#    '등록/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    'ㄹ래/EF',
#    '?/SF'],
#   ['등록/NNG', '하/XSV', 'ㅂ니다/EF', './SF'],
#   ['3/SN',
#    '째/XSN',
#    '주/NNB',
#    '일요일/NNP',
#    '오전/NNP',
#    '9/SN',
#    '시/NNB',
#    '에/JKB',
#    '알람/NNP',
#    '을/JKO',
#    '설정/NNG',
#    '하/XSV',
#    '아/EC',
#    '주/VX',
#    '어/EF',
#    './SF'],
#   ['네/IC', ',/SP', '알람/NNP', '을/JKO', '설정/NNG', '하/XSV', 'ㅂ니다/EF', './SF'],
#   ['아름/NNP', '아/JKV', '수고/NNG', '하/XSV', '았/EP', '어/EF', './SF'],
#   ['아니/VCN', '에요/EF', './SF']]]

# %%
tag_list = ['NNP', 'NNG', 'VV']
b = []
for i in docs:
    a = []
    for j in i:
        for k in j:
            if '/' in k:
                if k.split('/')[1] in tag_list:
                    a.append(k)
    b.append(a)

# %%
b
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  []]

# %%
a = [[['dk'], ['te']], [['fee', 'feef'], ['']],[['we', 'are'], ['future']]]

# %%
list(a)
# Out:
# [[['dk'], ['te']], [['fee', 'feef'], ['']], [['we', 'are'], ['future']]]

# %%
b = []
for idx, i in enumerate(a):
    #print(i)
    b.append(i)
print(b)
# Out:
# [[['dk'], ['te']], [['fee', 'feef'], ['']], [['we', 'are'], ['future']]]

# %%
save_file_name = 'test1'
with open('./'+save_file_name+'.txt', 'w', encoding='utf-8', newline='') as writer_text:
    for idx, i in enumerate(b):
        num = '(대화{})'.format(idx)
        writer_text.writelines(num + '\n')
        for j in i:
            for k in j:
                writer_text.writelines(str(k) + '\t')
        writer_text.writelines('\n')
